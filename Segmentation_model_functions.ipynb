# %% [markdown]
# <a href="https://colab.research.google.com/github/eternallysunny/ELTE_AI-ML_Final_Project/blob/main/Segmentation_model_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VGG16 model version 2

# %%
def VGG16Model_v2(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES):
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    x = inputs
    
    # Block 1
    c1 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(x)
    c1 = BatchNormalization()(c1)
    d1 = Dropout(0.2)(c1)
    c1 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d1)
    c1 = BatchNormalization()(c1)
    p1 = MaxPooling2D(pool_size = (2, 2))(c1)

    # Block 2
    c2 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(p1)
    c2 = BatchNormalization()(c2)
    d2 = Dropout(0.2)(c2)
    c2 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d2)
    c2 = BatchNormalization()(c2)
    p2 = MaxPooling2D(pool_size = (2, 2))(c2)

    # Block 3
    c3 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(p2)
    c3 = BatchNormalization()(c3)
    d3 = Dropout(0.1)(c3)
    c3 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d3)
    c3 = BatchNormalization()(c3)
    d3 = Dropout(0.1)(c3)
    c3 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d3)
    c3 = BatchNormalization()(c3)
    p3 = MaxPooling2D(pool_size = (2, 2))(c3)

    # Block 4
    c4 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(p3)
    c4 = BatchNormalization()(c4)
    d4 = Dropout(0.1)(c4)    
    c4 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d4)
    c4 = BatchNormalization()(c4)
    d4 = Dropout(0.1)(c4)
    c4 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d4)
    c4 = BatchNormalization()(c4)
    p4 = MaxPooling2D(pool_size = (2, 2))(c4)

    # Block 5 
    c5 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(p4)
    c5 = BatchNormalization()(c5)
    d5 = Dropout(0.1)(c5)    
    c5 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d5)
    c5 = BatchNormalization()(c5)
    d5 = Dropout(0.1)(c5)
    c5 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d5)
    c5 = BatchNormalization()(c5)
    p5 = MaxPooling2D(pool_size = (2, 2))(c5)
    
    # Fully connected block
    f6 = Flatten()(p5)
    c6 = Dense(1000, activation = 'relu')(f6)
    c6 = Dense(1000, activation = 'relu')(c6)
    c6 = Dense(65536, activation = 'softmax')(c6)
    
    # Reshape tensors to 2D matrix from vector
    outputs = tf.reshape(c6, (-1, IMG_HEIGHT, IMG_WIDTH, N_CLASSES))
    
    model = Model(inputs, outputs, name = 'VGG16_v2')
    
    return model

# %%
vgg16_model_v2 = VGG16Model_v2(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES)
vgg16_model_v2.compile(optimizer = OPTIMIZER (learning_rate = LEARNING_RATE_small), 
                      loss = LOSS, 
                      metrics = METRICS)
vgg16_model_v2.summary()
# Out:
# Model: "VGG16_v2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d_79 (Conv2D)          (None, 256, 256, 64)      1792
#
#  batch_normalization_76 (Bat  (None, 256, 256, 64)     256
#  chNormalization)
#
#  dropout_53 (Dropout)        (None, 256, 256, 64)      0
#
#  conv2d_80 (Conv2D)          (None, 256, 256, 64)      36928
#
#  batch_normalization_77 (Bat  (None, 256, 256, 64)     256
#  chNormalization)
#
#  max_pooling2d_20 (MaxPoolin  (None, 128, 128, 64)     0
#  g2D)
#
#  conv2d_81 (Conv2D)          (None, 128, 128, 128)     73856
#
#  batch_normalization_78 (Bat  (None, 128, 128, 128)    512
#  chNormalization)
#
#  dropout_54 (Dropout)        (None, 128, 128, 128)     0
#
#  conv2d_82 (Conv2D)          (None, 128, 128, 128)     147584
#
#  batch_normalization_79 (Bat  (None, 128, 128, 128)    512
#  chNormalization)
#
#  max_pooling2d_21 (MaxPoolin  (None, 64, 64, 128)      0
#  g2D)
#
#  conv2d_83 (Conv2D)          (None, 64, 64, 256)       295168
#
#  batch_normalization_80 (Bat  (None, 64, 64, 256)      1024
#  chNormalization)
#
#  dropout_55 (Dropout)        (None, 64, 64, 256)       0
#
#  conv2d_84 (Conv2D)          (None, 64, 64, 256)       590080
#
#  batch_normalization_81 (Bat  (None, 64, 64, 256)      1024
#  chNormalization)
#
#  dropout_56 (Dropout)        (None, 64, 64, 256)       0
#
#  conv2d_85 (Conv2D)          (None, 64, 64, 256)       590080
#
#  batch_normalization_82 (Bat  (None, 64, 64, 256)      1024
#  chNormalization)
#
#  max_pooling2d_22 (MaxPoolin  (None, 32, 32, 256)      0
#  g2D)
#
#  conv2d_86 (Conv2D)          (None, 32, 32, 512)       1180160
#
#  batch_normalization_83 (Bat  (None, 32, 32, 512)      2048
#  chNormalization)
#
#  dropout_57 (Dropout)        (None, 32, 32, 512)       0
#
#  conv2d_87 (Conv2D)          (None, 32, 32, 512)       2359808
#
#  batch_normalization_84 (Bat  (None, 32, 32, 512)      2048
#  chNormalization)
#
#  dropout_58 (Dropout)        (None, 32, 32, 512)       0
#
#  conv2d_88 (Conv2D)          (None, 32, 32, 512)       2359808
#
#  batch_normalization_85 (Bat  (None, 32, 32, 512)      2048
#  chNormalization)
#
#  max_pooling2d_23 (MaxPoolin  (None, 16, 16, 512)      0
#  g2D)
#
#  conv2d_89 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  batch_normalization_86 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  dropout_59 (Dropout)        (None, 16, 16, 512)       0
#
#  conv2d_90 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  batch_normalization_87 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  dropout_60 (Dropout)        (None, 16, 16, 512)       0
#
#  conv2d_91 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  batch_normalization_88 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  max_pooling2d_24 (MaxPoolin  (None, 8, 8, 512)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_6 (Dense)             (None, 1000)              32769000
#
#  dense_7 (Dense)             (None, 1000)              1001000
#
#  dense_8 (Dense)             (None, 65536)             65601536
#
#  tf.reshape_1 (TFOpLambda)   (None, 256, 256, 1)       0
#
# =================================================================
# Total params: 114,103,120
# Trainable params: 114,094,672
# Non-trainable params: 8,448
# _________________________________________________________________

# %%
vgg16_train_v2 = vgg16_model_v2.fit(train_gen_small,
                                  validation_data=val_gen_small,
                                  epochs = EPOCHS,
                                  steps_per_epoch = STEPS_PER_EPOCH_small,
                                  validation_steps = VALIDATION_STEPS_small,
                                  verbose = True)
# Out:
# Epoch 1/25
# 563/563 [==============================] - 95s 161ms/step - loss: 1.9625 - accuracy: 0.8190 - val_loss: 2.0471 - val_accuracy: 0.8107
# Epoch 2/25
# 563/563 [==============================] - 90s 160ms/step - loss: 1.9543 - accuracy: 0.8191 - val_loss: 2.0525 - val_accuracy: 0.8102
# Epoch 3/25
# 563/563 [==============================] - 90s 159ms/step - loss: 1.9544 - accuracy: 0.8189 - val_loss: 2.0589 - val_accuracy: 0.8093
# Epoch 4/25
# 563/563 [==============================] - 89s 158ms/step - loss: 1.9454 - accuracy: 0.8191 - val_loss: 2.0383 - val_accuracy: 0.8115
# Epoch 5/25
# 563/563 [==============================] - 89s 159ms/step - loss: 1.9390 - accuracy: 0.8191 - val_loss: 2.0402 - val_accuracy: 0.8107
# Epoch 6/25
# 563/563 [==============================] - 89s 159ms/step - loss: 1.9328 - accuracy: 0.8191 - val_loss: 2.0398 - val_accuracy: 0.8109
# Epoch 7/25
# 563/563 [==============================] - 89s 159ms/step - loss: 1.9269 - accuracy: 0.8190 - val_loss: 2.0520 - val_accuracy: 0.8093
# Epoch 8/25
# 563/563 [==============================] - 89s 159ms/step - loss: 1.9214 - accuracy: 0.8189 - val_loss: 2.0529 - val_accuracy: 0.8096
# Epoch 9/25
# 563/563 [==============================] - 89s 159ms/step - loss: 1.9126 - accuracy: 0.8190 - val_loss: 2.0550 - val_accuracy: 0.8109
# Epoch 10/25
# 563/563 [==============================] - 89s 159ms/step - loss: 1.9071 - accuracy: 0.8190 - val_loss: 2.0491 - val_accuracy: 0.8097
# Epoch 11/25
# 563/563 [==============================] - 90s 159ms/step - loss: 1.9011 - accuracy: 0.8190 - val_loss: 2.0359 - val_accuracy: 0.8107
# Epoch 12/25
# 563/563 [==============================] - 89s 159ms/step - loss: 1.8956 - accuracy: 0.8189 - val_loss: 2.0555 - val_accuracy: 0.8096
# Epoch 13/25
# 563/563 [==============================] - 90s 159ms/step - loss: 1.8905 - accuracy: 0.8189 - val_loss: 2.0208 - val_accuracy: 0.8117
# Epoch 14/25
# 563/563 [==============================] - 89s 159ms/step - loss: 1.8835 - accuracy: 0.8189 - val_loss: 2.0542 - val_accuracy: 0.8090
# Epoch 15/25
# 563/563 [==============================] - 90s 159ms/step - loss: 1.8739 - accuracy: 0.8193 - val_loss: 2.0341 - val_accuracy: 0.8119
# Epoch 16/25
# 563/563 [==============================] - 89s 159ms/step - loss: 1.8732 - accuracy: 0.8190 - val_loss: 2.0612 - val_accuracy: 0.8092
# Epoch 17/25
# 563/563 [==============================] - 90s 159ms/step - loss: 1.8677 - accuracy: 0.8191 - val_loss: 2.0519 - val_accuracy: 0.8103
# Epoch 18/25
# 563/563 [==============================] - 90s 159ms/step - loss: 1.8643 - accuracy: 0.8190 - val_loss: 2.0506 - val_accuracy: 0.8108
# Epoch 19/25
# 563/563 [==============================] - 89s 159ms/step - loss: 1.8604 - accuracy: 0.8190 - val_loss: 2.0493 - val_accuracy: 0.8109
# Epoch 20/25
# 563/563 [==============================] - 90s 159ms/step - loss: 1.8566 - accuracy: 0.8191 - val_loss: 2.0699 - val_accuracy: 0.8077
# Epoch 21/25
# 563/563 [==============================] - 90s 159ms/step - loss: 1.8554 - accuracy: 0.8188 - val_loss: 2.0433 - val_accuracy: 0.8104
# Epoch 22/25
# 563/563 [==============================] - 90s 160ms/step - loss: 1.8516 - accuracy: 0.8190 - val_loss: 2.0150 - val_accuracy: 0.8130
# Epoch 23/25
# 563/563 [==============================] - 90s 160ms/step - loss: 1.8488 - accuracy: 0.8190 - val_loss: 2.0458 - val_accuracy: 0.8091
# Epoch 24/25
# 563/563 [==============================] - 90s 160ms/step - loss: 1.8467 - accuracy: 0.8190 - val_loss: 2.0468 - val_accuracy: 0.8100
# Epoch 25/25
# 563/563 [==============================] - 90s 159ms/step - loss: 1.8453 - accuracy: 0.8189 - val_loss: 2.0297 - val_accuracy: 0.8110

# %%
vgg16_model_v2.save('vgg16_v2')
# Out:
# [WARNING] save:__init__:233 - Found untraced functions such as %s while saving (showing %d of %d). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# [INFO   ] builder_impl:copy_assets_to_destination_dir:779 - Assets written to: %s
# INFO:tensorflow:Assets written to: vgg16_v2\assets
# INFO:tensorflow:Assets written to: vgg16_v2\assets

# %% [markdown]
# # VGG19 model version 2

# %%
def VGG19Model_v2(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES):
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    x = inputs
    
    # Block 1
    c1 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(x)
    c1 = BatchNormalization()(c1)
    d1 = Dropout(0.2)(c1)
    c1 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d1)
    c1 = BatchNormalization()(c1)
    p1 = MaxPooling2D(pool_size = (2, 2))(c1)

    # Block 2
    c2 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(p1)
    c2 = BatchNormalization()(c2)
    d2 = Dropout(0.2)(c2)
    c2 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d2)
    c2 = BatchNormalization()(c2)
    p2 = MaxPooling2D(pool_size = (2, 2))(c2)

    # Block 3
    c3 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(p2)
    c3 = BatchNormalization()(c3)
    d3 = Dropout(0.1)(c3)
    c3 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d3)
    c3 = BatchNormalization()(c3)
    d3 = Dropout(0.1)(c3)
    c3 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d3)
    c3 = BatchNormalization()(c3)
    d3 = Dropout(0.1)(c3)
    c3 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d3)
    c3 = BatchNormalization()(c3)
    p3 = MaxPooling2D(pool_size = (2, 2))(c3)

    # Block 4
    c4 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(p3)
    c4 = BatchNormalization()(c4)
    d4 = Dropout(0.1)(c4)    
    c4 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d4)
    c4 = BatchNormalization()(c4)
    d4 = Dropout(0.1)(c4)
    c4 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d4)
    c4 = BatchNormalization()(c4)
    d4 = Dropout(0.1)(c4)
    c4 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d4)
    c4 = BatchNormalization()(c4)
    p4 = MaxPooling2D(pool_size = (2, 2))(c4)

    # Block 5 
    c5 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(p4)
    c5 = BatchNormalization()(c5)
    d5 = Dropout(0.1)(c5)    
    c5 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d5)
    c5 = BatchNormalization()(c5)
    d5 = Dropout(0.1)(c5)
    c5 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d5)
    c5 = BatchNormalization()(c5)
    d5 = Dropout(0.1)(c5)
    c5 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d5)
    c5 = BatchNormalization()(c5)
    p5 = MaxPooling2D(pool_size = (2, 2))(c5)
    
    # Fully connected block
    f6 = Flatten()(p5)
    c6 = Dense(1000, activation = 'relu')(f6)
    c6 = Dense(1000, activation = 'relu')(c6)
    c6 = Dense(65536, activation = 'softmax')(c6)
    
    # Reshape tensors to 2D matrix from vector
    outputs = tf.reshape(c6, (-1, IMG_HEIGHT, IMG_WIDTH, N_CLASSES))
    
    model = Model(inputs, outputs, name = 'VGG19_v2')
    
    return model

# %%
vgg19_model_v2 = VGG19Model_v2(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES)
vgg19_model_v2.compile(optimizer = OPTIMIZER (learning_rate = LEARNING_RATE_small), 
                      loss = LOSS, 
                      metrics = METRICS)
vgg19_model_v2.summary()
# Out:
# Model: "VGG19_v2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d_38 (Conv2D)          (None, 256, 256, 64)      1792
#
#  batch_normalization_37 (Bat  (None, 256, 256, 64)     256
#  chNormalization)
#
#  dropout_26 (Dropout)        (None, 256, 256, 64)      0
#
#  conv2d_39 (Conv2D)          (None, 256, 256, 64)      36928
#
#  batch_normalization_38 (Bat  (None, 256, 256, 64)     256
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 128, 128, 64)     0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 128, 128, 128)     73856
#
#  batch_normalization_39 (Bat  (None, 128, 128, 128)    512
#  chNormalization)
#
#  dropout_27 (Dropout)        (None, 128, 128, 128)     0
#
#  conv2d_41 (Conv2D)          (None, 128, 128, 128)     147584
#
#  batch_normalization_40 (Bat  (None, 128, 128, 128)    512
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 64, 64, 128)      0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 256)       295168
#
#  batch_normalization_41 (Bat  (None, 64, 64, 256)      1024
#  chNormalization)
#
#  dropout_28 (Dropout)        (None, 64, 64, 256)       0
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 256)       590080
#
#  batch_normalization_42 (Bat  (None, 64, 64, 256)      1024
#  chNormalization)
#
#  dropout_29 (Dropout)        (None, 64, 64, 256)       0
#
#  conv2d_44 (Conv2D)          (None, 64, 64, 256)       590080
#
#  batch_normalization_43 (Bat  (None, 64, 64, 256)      1024
#  chNormalization)
#
#  dropout_30 (Dropout)        (None, 64, 64, 256)       0
#
#  conv2d_45 (Conv2D)          (None, 64, 64, 256)       590080
#
#  batch_normalization_44 (Bat  (None, 64, 64, 256)      1024
#  chNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 32, 32, 256)      0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 32, 32, 512)       1180160
#
#  batch_normalization_45 (Bat  (None, 32, 32, 512)      2048
#  chNormalization)
#
#  dropout_31 (Dropout)        (None, 32, 32, 512)       0
#
#  conv2d_47 (Conv2D)          (None, 32, 32, 512)       2359808
#
#  batch_normalization_46 (Bat  (None, 32, 32, 512)      2048
#  chNormalization)
#
#  dropout_32 (Dropout)        (None, 32, 32, 512)       0
#
#  conv2d_48 (Conv2D)          (None, 32, 32, 512)       2359808
#
#  batch_normalization_47 (Bat  (None, 32, 32, 512)      2048
#  chNormalization)
#
#  dropout_33 (Dropout)        (None, 32, 32, 512)       0
#
#  conv2d_49 (Conv2D)          (None, 32, 32, 512)       2359808
#
#  batch_normalization_48 (Bat  (None, 32, 32, 512)      2048
#  chNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 16, 16, 512)      0
#  g2D)
#
#  conv2d_50 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  batch_normalization_49 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  dropout_34 (Dropout)        (None, 16, 16, 512)       0
#
#  conv2d_51 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  batch_normalization_50 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  dropout_35 (Dropout)        (None, 16, 16, 512)       0
#
#  conv2d_52 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  batch_normalization_51 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  dropout_36 (Dropout)        (None, 16, 16, 512)       0
#
#  conv2d_53 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  batch_normalization_52 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 8, 8, 512)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_4 (Dense)             (None, 1000)              32769000
#
#  dense_5 (Dense)             (None, 1000)              1001000
#
#  dense_6 (Dense)             (None, 65536)             65601536
#
#  tf.reshape_1 (TFOpLambda)   (None, 256, 256, 1)       0
#
# =================================================================
# Total params: 119,417,936
# Trainable params: 119,406,928
# Non-trainable params: 11,008
# _________________________________________________________________

# %%
vgg19_train_v2 = vgg19_model_v2.fit(train_gen_small,
                                  validation_data=val_gen_small,
                                  epochs = EPOCHS,
                                  steps_per_epoch = STEPS_PER_EPOCH_small,
                                  validation_steps = VALIDATION_STEPS_small,
                                  verbose = True)
# Out:
# Epoch 1/25
# 563/563 [==============================] - 104s 181ms/step - loss: 1.9609 - accuracy: 0.8191 - val_loss: 2.0320 - val_accuracy: 0.8121
# Epoch 2/25
# 563/563 [==============================] - 102s 182ms/step - loss: 1.9544 - accuracy: 0.8191 - val_loss: 2.0733 - val_accuracy: 0.8085
# Epoch 3/25
# 563/563 [==============================] - 102s 182ms/step - loss: 1.9535 - accuracy: 0.8191 - val_loss: 2.0555 - val_accuracy: 0.8098
# Epoch 4/25
# 563/563 [==============================] - 102s 182ms/step - loss: 1.9505 - accuracy: 0.8188 - val_loss: 2.0239 - val_accuracy: 0.8123
# Epoch 5/25
# 563/563 [==============================] - 102s 182ms/step - loss: 1.9438 - accuracy: 0.8190 - val_loss: 2.0392 - val_accuracy: 0.8112
# Epoch 6/25
# 563/563 [==============================] - 102s 182ms/step - loss: 1.9389 - accuracy: 0.8190 - val_loss: 2.0824 - val_accuracy: 0.8073
# Epoch 7/25
# 563/563 [==============================] - 102s 182ms/step - loss: 1.9346 - accuracy: 0.8190 - val_loss: 2.0571 - val_accuracy: 0.8091
# Epoch 8/25
# 563/563 [==============================] - 102s 182ms/step - loss: 1.9315 - accuracy: 0.8188 - val_loss: 2.0184 - val_accuracy: 0.8125
# Epoch 9/25
# 563/563 [==============================] - 102s 182ms/step - loss: 1.9224 - accuracy: 0.8192 - val_loss: 2.0586 - val_accuracy: 0.8096
# Epoch 10/25
# 563/563 [==============================] - 102s 182ms/step - loss: 1.9205 - accuracy: 0.8188 - val_loss: 2.0645 - val_accuracy: 0.8092
# Epoch 11/25
# 563/563 [==============================] - 102s 182ms/step - loss: 1.9112 - accuracy: 0.8192 - val_loss: 2.0433 - val_accuracy: 0.8108
# Epoch 12/25
# 563/563 [==============================] - 103s 183ms/step - loss: 1.9078 - accuracy: 0.8190 - val_loss: 2.0009 - val_accuracy: 0.8143
# Epoch 13/25
# 563/563 [==============================] - 102s 181ms/step - loss: 1.9020 - accuracy: 0.8190 - val_loss: 2.0549 - val_accuracy: 0.8089
# Epoch 14/25
# 563/563 [==============================] - 102s 181ms/step - loss: 1.8991 - accuracy: 0.8187 - val_loss: 2.0844 - val_accuracy: 0.8069
# Epoch 15/25
# 563/563 [==============================] - 102s 181ms/step - loss: 1.8928 - accuracy: 0.8189 - val_loss: 2.0054 - val_accuracy: 0.8132
# Epoch 16/25
# 563/563 [==============================] - 102s 182ms/step - loss: 1.8880 - accuracy: 0.8188 - val_loss: 2.0568 - val_accuracy: 0.8090
# Epoch 17/25
# 563/563 [==============================] - 102s 181ms/step - loss: 1.8783 - accuracy: 0.8192 - val_loss: 2.0668 - val_accuracy: 0.8076
# Epoch 18/25
# 563/563 [==============================] - 102s 182ms/step - loss: 1.8768 - accuracy: 0.8189 - val_loss: 1.9976 - val_accuracy: 0.8142
# Epoch 19/25
# 563/563 [==============================] - 102s 181ms/step - loss: 1.8694 - accuracy: 0.8191 - val_loss: 2.0649 - val_accuracy: 0.8078
# Epoch 20/25
# 563/563 [==============================] - 103s 182ms/step - loss: 1.8697 - accuracy: 0.8188 - val_loss: 2.0485 - val_accuracy: 0.8092
# Epoch 21/25
# 563/563 [==============================] - 102s 182ms/step - loss: 1.8599 - accuracy: 0.8193 - val_loss: 2.0032 - val_accuracy: 0.8136
# Epoch 22/25
# 563/563 [==============================] - 103s 182ms/step - loss: 1.8595 - accuracy: 0.8190 - val_loss: 2.0256 - val_accuracy: 0.8111
# Epoch 23/25
# 563/563 [==============================] - 103s 182ms/step - loss: 1.8561 - accuracy: 0.8191 - val_loss: 2.0210 - val_accuracy: 0.8119
# Epoch 24/25
# 563/563 [==============================] - 103s 183ms/step - loss: 1.8526 - accuracy: 0.8191 - val_loss: 2.0437 - val_accuracy: 0.8102
# Epoch 25/25
# 563/563 [==============================] - 105s 187ms/step - loss: 1.8539 - accuracy: 0.8187 - val_loss: 2.0398 - val_accuracy: 0.8109

# %%
vgg19_model_v2.save('vgg19_v2')
# Out:
# [WARNING] save:__init__:233 - Found untraced functions such as %s while saving (showing %d of %d). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# [INFO   ] builder_impl:copy_assets_to_destination_dir:779 - Assets written to: %s
# INFO:tensorflow:Assets written to: vgg19_v2\assets
# INFO:tensorflow:Assets written to: vgg19_v2\assets

# %% [markdown]
# # ResNet50

# %%
def identity_block(X, f, filters, stage, block):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters

    X_shortcut = X
   
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2a')(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b')(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c')(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X = Add()([X, X_shortcut])# SKIP Connection
    X = Activation('relu')(X)

    return X

def convolutional_block(X, f, filters, stage, block, s=2):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '2a')(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b')(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c')(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '1')(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=bn_name_base + '1')(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def ResNetModel_v1(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))

    X = ZeroPadding2D((3, 3))(inputs)

    X = Conv2D(64, (7, 7), strides=(2, 2), name='conv1')(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    X = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

    X = convolutional_block(X, f=3, filters=[128, 128, 512], stage=3, block='a', s=2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    X = convolutional_block(X, f=3, filters=[256, 256, 1024], stage=4, block='a', s=2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    X = X = convolutional_block(X, f=3, filters=[512, 512, 2048], stage=5, block='a', s=2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)
    
    # Fully connected block
    X = Flatten()(X)
    X = Dense(125, activation = 'relu')(X)
    X = Dense(65536, activation = 'softmax')(X)
    
    # Reshape tensors to 2D matrix from vector
    outputs = tf.reshape(X, (-1, IMG_HEIGHT, IMG_WIDTH, N_CLASSES))
    
    model = Model(inputs, outputs, name = 'ResNet_v1')

    return model

# %%
resnet_model_v1 = ResNetModel_v1(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES)
resnet_model_v1.compile(optimizer = OPTIMIZER (learning_rate = LEARNING_RATE_small), 
                          loss = LOSS, 
                          metrics = METRICS)
resnet_model_v1.summary()
# Out:
# Model: "ResNet_v1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 262, 262, 3)  0          ['input_5[0][0]']
#  D)
#
#  conv1 (Conv2D)                 (None, 128, 128, 64  9472        ['zero_padding2d_2[0][0]']
#                                 )
#
#  bn_conv1 (BatchNormalization)  (None, 128, 128, 64  256         ['conv1[0][0]']
#                                 )
#
#  activation_33 (Activation)     (None, 128, 128, 64  0           ['bn_conv1[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 63, 63, 64)  0           ['activation_33[0][0]']
#
#  res2a_branch2a (Conv2D)        (None, 63, 63, 64)   4160        ['max_pooling2d_2[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 63, 63, 64)  256         ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_34 (Activation)     (None, 63, 63, 64)   0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 63, 63, 64)   36928       ['activation_34[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 63, 63, 64)  256         ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_35 (Activation)     (None, 63, 63, 64)   0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv2D)        (None, 63, 63, 256)  16640       ['activation_35[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 63, 63, 256)  16640       ['max_pooling2d_2[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 63, 63, 256)  1024       ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 63, 63, 256)  1024       ['res2a_branch1[0][0]']
#  on)
#
#  add_13 (Add)                   (None, 63, 63, 256)  0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_36 (Activation)     (None, 63, 63, 256)  0           ['add_13[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 63, 63, 64)   16448       ['activation_36[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 63, 63, 64)  256         ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_37 (Activation)     (None, 63, 63, 64)   0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 63, 63, 64)   36928       ['activation_37[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 63, 63, 64)  256         ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_38 (Activation)     (None, 63, 63, 64)   0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv2D)        (None, 63, 63, 256)  16640       ['activation_38[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 63, 63, 256)  1024       ['res2b_branch2c[0][0]']
#  ion)
#
#  add_14 (Add)                   (None, 63, 63, 256)  0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 63, 63, 256)  0           ['add_14[0][0]']
#
#  res2c_branch2a (Conv2D)        (None, 63, 63, 64)   16448       ['activation_39[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 63, 63, 64)  256         ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_40 (Activation)     (None, 63, 63, 64)   0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv2D)        (None, 63, 63, 64)   36928       ['activation_40[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 63, 63, 64)  256         ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_41 (Activation)     (None, 63, 63, 64)   0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv2D)        (None, 63, 63, 256)  16640       ['activation_41[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 63, 63, 256)  1024       ['res2c_branch2c[0][0]']
#  ion)
#
#  add_15 (Add)                   (None, 63, 63, 256)  0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_39[0][0]']
#
#  activation_42 (Activation)     (None, 63, 63, 256)  0           ['add_15[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 32, 32, 128)  32896       ['activation_42[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 32, 32, 128)  512        ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_43 (Activation)     (None, 32, 32, 128)  0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 32, 32, 128)  147584      ['activation_43[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 32, 32, 128)  512        ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_44 (Activation)     (None, 32, 32, 128)  0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv2D)        (None, 32, 32, 512)  66048       ['activation_44[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 32, 32, 512)  131584      ['activation_42[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 32, 32, 512)  2048       ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 32, 32, 512)  2048       ['res3a_branch1[0][0]']
#  on)
#
#  add_16 (Add)                   (None, 32, 32, 512)  0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_45 (Activation)     (None, 32, 32, 512)  0           ['add_16[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 32, 32, 128)  65664       ['activation_45[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 32, 32, 128)  512        ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_46 (Activation)     (None, 32, 32, 128)  0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 32, 32, 128)  147584      ['activation_46[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 32, 32, 128)  512        ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_47 (Activation)     (None, 32, 32, 128)  0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv2D)        (None, 32, 32, 512)  66048       ['activation_47[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 32, 32, 512)  2048       ['res3b_branch2c[0][0]']
#  ion)
#
#  add_17 (Add)                   (None, 32, 32, 512)  0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 32, 32, 512)  0           ['add_17[0][0]']
#
#  res3c_branch2a (Conv2D)        (None, 32, 32, 128)  65664       ['activation_48[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 32, 32, 128)  512        ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_49 (Activation)     (None, 32, 32, 128)  0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv2D)        (None, 32, 32, 128)  147584      ['activation_49[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 32, 32, 128)  512        ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_50 (Activation)     (None, 32, 32, 128)  0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv2D)        (None, 32, 32, 512)  66048       ['activation_50[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 32, 32, 512)  2048       ['res3c_branch2c[0][0]']
#  ion)
#
#  add_18 (Add)                   (None, 32, 32, 512)  0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_48[0][0]']
#
#  activation_51 (Activation)     (None, 32, 32, 512)  0           ['add_18[0][0]']
#
#  res3d_branch2a (Conv2D)        (None, 32, 32, 128)  65664       ['activation_51[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 32, 32, 128)  512        ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_52 (Activation)     (None, 32, 32, 128)  0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv2D)        (None, 32, 32, 128)  147584      ['activation_52[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 32, 32, 128)  512        ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_53 (Activation)     (None, 32, 32, 128)  0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv2D)        (None, 32, 32, 512)  66048       ['activation_53[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 32, 32, 512)  2048       ['res3d_branch2c[0][0]']
#  ion)
#
#  add_19 (Add)                   (None, 32, 32, 512)  0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_51[0][0]']
#
#  activation_54 (Activation)     (None, 32, 32, 512)  0           ['add_19[0][0]']
#
#  res4a_branch2a (Conv2D)        (None, 16, 16, 256)  131328      ['activation_54[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_55 (Activation)     (None, 16, 16, 256)  0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_55[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_56 (Activation)     (None, 16, 16, 256)  0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_56[0][0]']
#                                 )
#
#  res4a_branch1 (Conv2D)         (None, 16, 16, 1024  525312      ['activation_54[0][0]']
#                                 )
#
#  bn4a_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4a_branch2c[0][0]']
#  ion)                           )
#
#  bn4a_branch1 (BatchNormalizati  (None, 16, 16, 1024  4096       ['res4a_branch1[0][0]']
#  on)                            )
#
#  add_20 (Add)                   (None, 16, 16, 1024  0           ['bn4a_branch2c[0][0]',
#                                 )                                 'bn4a_branch1[0][0]']
#
#  activation_57 (Activation)     (None, 16, 16, 1024  0           ['add_20[0][0]']
#                                 )
#
#  res4b_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_57[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4b_branch2a[0][0]']
#  ion)
#
#  activation_58 (Activation)     (None, 16, 16, 256)  0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_58[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4b_branch2b[0][0]']
#  ion)
#
#  activation_59 (Activation)     (None, 16, 16, 256)  0           ['bn4b_branch2b[0][0]']
#
#  res4b_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_59[0][0]']
#                                 )
#
#  bn4b_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4b_branch2c[0][0]']
#  ion)                           )
#
#  add_21 (Add)                   (None, 16, 16, 1024  0           ['bn4b_branch2c[0][0]',
#                                 )                                 'activation_57[0][0]']
#
#  activation_60 (Activation)     (None, 16, 16, 1024  0           ['add_21[0][0]']
#                                 )
#
#  res4c_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_60[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4c_branch2a[0][0]']
#  ion)
#
#  activation_61 (Activation)     (None, 16, 16, 256)  0           ['bn4c_branch2a[0][0]']
#
#  res4c_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_61[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4c_branch2b[0][0]']
#  ion)
#
#  activation_62 (Activation)     (None, 16, 16, 256)  0           ['bn4c_branch2b[0][0]']
#
#  res4c_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_62[0][0]']
#                                 )
#
#  bn4c_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4c_branch2c[0][0]']
#  ion)                           )
#
#  add_22 (Add)                   (None, 16, 16, 1024  0           ['bn4c_branch2c[0][0]',
#                                 )                                 'activation_60[0][0]']
#
#  activation_63 (Activation)     (None, 16, 16, 1024  0           ['add_22[0][0]']
#                                 )
#
#  res4d_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_63[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4d_branch2a[0][0]']
#  ion)
#
#  activation_64 (Activation)     (None, 16, 16, 256)  0           ['bn4d_branch2a[0][0]']
#
#  res4d_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_64[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4d_branch2b[0][0]']
#  ion)
#
#  activation_65 (Activation)     (None, 16, 16, 256)  0           ['bn4d_branch2b[0][0]']
#
#  res4d_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_65[0][0]']
#                                 )
#
#  bn4d_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4d_branch2c[0][0]']
#  ion)                           )
#
#  add_23 (Add)                   (None, 16, 16, 1024  0           ['bn4d_branch2c[0][0]',
#                                 )                                 'activation_63[0][0]']
#
#  activation_66 (Activation)     (None, 16, 16, 1024  0           ['add_23[0][0]']
#                                 )
#
#  res4e_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_66[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4e_branch2a[0][0]']
#  ion)
#
#  activation_67 (Activation)     (None, 16, 16, 256)  0           ['bn4e_branch2a[0][0]']
#
#  res4e_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_67[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4e_branch2b[0][0]']
#  ion)
#
#  activation_68 (Activation)     (None, 16, 16, 256)  0           ['bn4e_branch2b[0][0]']
#
#  res4e_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_68[0][0]']
#                                 )
#
#  bn4e_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4e_branch2c[0][0]']
#  ion)                           )
#
#  add_24 (Add)                   (None, 16, 16, 1024  0           ['bn4e_branch2c[0][0]',
#                                 )                                 'activation_66[0][0]']
#
#  activation_69 (Activation)     (None, 16, 16, 1024  0           ['add_24[0][0]']
#                                 )
#
#  res4f_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_69[0][0]']
#
#  bn4f_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4f_branch2a[0][0]']
#  ion)
#
#  activation_70 (Activation)     (None, 16, 16, 256)  0           ['bn4f_branch2a[0][0]']
#
#  res4f_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_70[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4f_branch2b[0][0]']
#  ion)
#
#  activation_71 (Activation)     (None, 16, 16, 256)  0           ['bn4f_branch2b[0][0]']
#
#  res4f_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_71[0][0]']
#                                 )
#
#  bn4f_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4f_branch2c[0][0]']
#  ion)                           )
#
#  add_25 (Add)                   (None, 16, 16, 1024  0           ['bn4f_branch2c[0][0]',
#                                 )                                 'activation_69[0][0]']
#
#  activation_72 (Activation)     (None, 16, 16, 1024  0           ['add_25[0][0]']
#                                 )
#
#  res5a_branch2a (Conv2D)        (None, 8, 8, 512)    524800      ['activation_72[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 8, 8, 512)   2048        ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_73 (Activation)     (None, 8, 8, 512)    0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)        (None, 8, 8, 512)    2359808     ['activation_73[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 8, 8, 512)   2048        ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_74 (Activation)     (None, 8, 8, 512)    0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv2D)        (None, 8, 8, 2048)   1050624     ['activation_74[0][0]']
#
#  res5a_branch1 (Conv2D)         (None, 8, 8, 2048)   2099200     ['activation_72[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 8, 8, 2048)  8192        ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 8, 8, 2048)  8192        ['res5a_branch1[0][0]']
#  on)
#
#  add_26 (Add)                   (None, 8, 8, 2048)   0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_75 (Activation)     (None, 8, 8, 2048)   0           ['add_26[0][0]']
#
#  res5b_branch2a (Conv2D)        (None, 8, 8, 512)    1049088     ['activation_75[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 8, 8, 512)   2048        ['res5b_branch2a[0][0]']
#  ion)
#
#  activation_76 (Activation)     (None, 8, 8, 512)    0           ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)        (None, 8, 8, 512)    2359808     ['activation_76[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 8, 8, 512)   2048        ['res5b_branch2b[0][0]']
#  ion)
#
#  activation_77 (Activation)     (None, 8, 8, 512)    0           ['bn5b_branch2b[0][0]']
#
#  res5b_branch2c (Conv2D)        (None, 8, 8, 2048)   1050624     ['activation_77[0][0]']
#
#  bn5b_branch2c (BatchNormalizat  (None, 8, 8, 2048)  8192        ['res5b_branch2c[0][0]']
#  ion)
#
#  add_27 (Add)                   (None, 8, 8, 2048)   0           ['bn5b_branch2c[0][0]',
#                                                                   'activation_75[0][0]']
#
#  activation_78 (Activation)     (None, 8, 8, 2048)   0           ['add_27[0][0]']
#
#  res5c_branch2a (Conv2D)        (None, 8, 8, 512)    1049088     ['activation_78[0][0]']
#
#  bn5c_branch2a (BatchNormalizat  (None, 8, 8, 512)   2048        ['res5c_branch2a[0][0]']
#  ion)
#
#  activation_79 (Activation)     (None, 8, 8, 512)    0           ['bn5c_branch2a[0][0]']
#
#  res5c_branch2b (Conv2D)        (None, 8, 8, 512)    2359808     ['activation_79[0][0]']
#
#  bn5c_branch2b (BatchNormalizat  (None, 8, 8, 512)   2048        ['res5c_branch2b[0][0]']
#  ion)
#
#  activation_80 (Activation)     (None, 8, 8, 512)    0           ['bn5c_branch2b[0][0]']
#
#  res5c_branch2c (Conv2D)        (None, 8, 8, 2048)   1050624     ['activation_80[0][0]']
#
#  bn5c_branch2c (BatchNormalizat  (None, 8, 8, 2048)  8192        ['res5c_branch2c[0][0]']
#  ion)
#
#  add_28 (Add)                   (None, 8, 8, 2048)   0           ['bn5c_branch2c[0][0]',
#                                                                   'activation_78[0][0]']
#
#  activation_81 (Activation)     (None, 8, 8, 2048)   0           ['add_28[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 4, 4, 2048)  0           ['activation_81[0][0]']
#  oling2D)
#
#  flatten_1 (Flatten)            (None, 32768)        0           ['average_pooling2d_1[0][0]']
#
#  dense_2 (Dense)                (None, 125)          4096125     ['flatten_1[0][0]']
#
#  dense_3 (Dense)                (None, 65536)        8257536     ['dense_2[0][0]']
#
#  tf.reshape_1 (TFOpLambda)      (None, 256, 256, 1)  0           ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 35,941,373
# Trainable params: 35,888,253
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
resnet_train_v1 = resnet_model_v1.fit(train_gen_small,
                                      validation_data=val_gen_small,
                                      epochs = EPOCHS,
                                      steps_per_epoch = STEPS_PER_EPOCH_small,
                                      validation_steps = VALIDATION_STEPS_small,
                                      verbose = True)
# Out:
# Epoch 1/25
# 563/563 [==============================] - 78s 127ms/step - loss: 1.9691 - accuracy: 0.8187 - val_loss: 2.0499 - val_accuracy: 0.8103
# Epoch 2/25
# 563/563 [==============================] - 58s 104ms/step - loss: 1.9551 - accuracy: 0.8191 - val_loss: 2.0410 - val_accuracy: 0.8110
# Epoch 3/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9566 - accuracy: 0.8189 - val_loss: 2.0473 - val_accuracy: 0.8106
# Epoch 4/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9571 - accuracy: 0.8188 - val_loss: 2.0529 - val_accuracy: 0.8100
# Epoch 5/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9552 - accuracy: 0.8189 - val_loss: 2.0376 - val_accuracy: 0.8114
# Epoch 6/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9532 - accuracy: 0.8191 - val_loss: 2.0631 - val_accuracy: 0.8091
# Epoch 7/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9548 - accuracy: 0.8189 - val_loss: 2.0308 - val_accuracy: 0.8120
# Epoch 8/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9570 - accuracy: 0.8187 - val_loss: 2.0556 - val_accuracy: 0.8097
# Epoch 9/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9512 - accuracy: 0.8191 - val_loss: 2.0659 - val_accuracy: 0.8088
# Epoch 10/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9523 - accuracy: 0.8189 - val_loss: 2.0485 - val_accuracy: 0.8103
# Epoch 11/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9523 - accuracy: 0.8188 - val_loss: 2.0292 - val_accuracy: 0.8120
# Epoch 12/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9493 - accuracy: 0.8189 - val_loss: 2.0370 - val_accuracy: 0.8109
# Epoch 13/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9497 - accuracy: 0.8188 - val_loss: 2.0697 - val_accuracy: 0.8080
# Epoch 14/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9428 - accuracy: 0.8191 - val_loss: 2.0474 - val_accuracy: 0.8100
# Epoch 15/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9411 - accuracy: 0.8191 - val_loss: 2.0223 - val_accuracy: 0.8119
# Epoch 16/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9444 - accuracy: 0.8185 - val_loss: 2.0292 - val_accuracy: 0.8114
# Epoch 17/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9335 - accuracy: 0.8193 - val_loss: 2.0250 - val_accuracy: 0.8116
# Epoch 18/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9356 - accuracy: 0.8189 - val_loss: 2.0655 - val_accuracy: 0.8078
# Epoch 19/25
# 563/563 [==============================] - 59s 105ms/step - loss: 1.9340 - accuracy: 0.8188 - val_loss: 2.0529 - val_accuracy: 0.8090
# Epoch 20/25
# 563/563 [==============================] - 60s 106ms/step - loss: 1.9264 - accuracy: 0.8194 - val_loss: 2.0180 - val_accuracy: 0.8120
# Epoch 21/25
# 563/563 [==============================] - 60s 106ms/step - loss: 1.9328 - accuracy: 0.8185 - val_loss: 2.0403 - val_accuracy: 0.8099
# Epoch 22/25
# 563/563 [==============================] - 60s 106ms/step - loss: 1.9244 - accuracy: 0.8191 - val_loss: 2.0205 - val_accuracy: 0.8120
# Epoch 23/25
# 563/563 [==============================] - 59s 106ms/step - loss: 1.9244 - accuracy: 0.8189 - val_loss: 2.0230 - val_accuracy: 0.8119
# Epoch 24/25
# 563/563 [==============================] - 60s 106ms/step - loss: 1.9246 - accuracy: 0.8187 - val_loss: 2.0690 - val_accuracy: 0.8079
# Epoch 25/25
# 563/563 [==============================] - 60s 106ms/step - loss: 1.9158 - accuracy: 0.8193 - val_loss: 2.0446 - val_accuracy: 0.8106

# %%
resnet_model_v1.save('resnet_v1')
# Out:
# [WARNING] save:__init__:233 - Found untraced functions such as %s while saving (showing %d of %d). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# [INFO   ] builder_impl:copy_assets_to_destination_dir:779 - Assets written to: %s
# INFO:tensorflow:Assets written to: resnet_v1\assets
# INFO:tensorflow:Assets written to: resnet_v1\assets

# %% [markdown]
# # ResNet101

# %%
def ResNetModel_v2(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))

    X = ZeroPadding2D((3, 3))(inputs)

    X = Conv2D(64, (7, 7), strides=(2, 2), name='conv1')(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    X = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

    X = convolutional_block(X, f=3, filters=[128, 128, 512], stage=3, block='a', s=2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    X = convolutional_block(X, f=3, filters=[256, 256, 1024], stage=4, block='a', s=2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='g')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='h')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='i')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='j')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='k')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='l')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='m')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='n')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='o')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='p')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='q')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='r')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='s')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='t')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='u')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='v')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='z')

    X = X = convolutional_block(X, f=3, filters=[512, 512, 2048], stage=5, block='a', s=2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)
    
    # Fully connected block
    X = Flatten()(X)
    X = Dense(125, activation = 'relu')(X)
    X = Dense(65536, activation = 'softmax')(X)
    
    # Reshape tensors to 2D matrix from vector
    outputs = tf.reshape(X, (-1, IMG_HEIGHT, IMG_WIDTH, N_CLASSES))
    
    model = Model(inputs, outputs, name = 'ResNet_v2')

    return model

# %%
resnet_model_v2 = ResNetModel_v2(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES)
resnet_model_v2.compile(optimizer = OPTIMIZER (learning_rate = LEARNING_RATE_small), 
                          loss = LOSS, 
                          metrics = METRICS)
resnet_model_v2.summary()
# Out:
# Model: "ResNet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  zero_padding2d_3 (ZeroPadding2  (None, 262, 262, 3)  0          ['input_6[0][0]']
#  D)
#
#  conv1 (Conv2D)                 (None, 128, 128, 64  9472        ['zero_padding2d_3[0][0]']
#                                 )
#
#  bn_conv1 (BatchNormalization)  (None, 128, 128, 64  256         ['conv1[0][0]']
#                                 )
#
#  activation_82 (Activation)     (None, 128, 128, 64  0           ['bn_conv1[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 63, 63, 64)  0           ['activation_82[0][0]']
#
#  res2a_branch2a (Conv2D)        (None, 63, 63, 64)   4160        ['max_pooling2d_3[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 63, 63, 64)  256         ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_83 (Activation)     (None, 63, 63, 64)   0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 63, 63, 64)   36928       ['activation_83[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 63, 63, 64)  256         ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_84 (Activation)     (None, 63, 63, 64)   0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv2D)        (None, 63, 63, 256)  16640       ['activation_84[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 63, 63, 256)  16640       ['max_pooling2d_3[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 63, 63, 256)  1024       ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 63, 63, 256)  1024       ['res2a_branch1[0][0]']
#  on)
#
#  add_29 (Add)                   (None, 63, 63, 256)  0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_85 (Activation)     (None, 63, 63, 256)  0           ['add_29[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 63, 63, 64)   16448       ['activation_85[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 63, 63, 64)  256         ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_86 (Activation)     (None, 63, 63, 64)   0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 63, 63, 64)   36928       ['activation_86[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 63, 63, 64)  256         ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_87 (Activation)     (None, 63, 63, 64)   0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv2D)        (None, 63, 63, 256)  16640       ['activation_87[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 63, 63, 256)  1024       ['res2b_branch2c[0][0]']
#  ion)
#
#  add_30 (Add)                   (None, 63, 63, 256)  0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_85[0][0]']
#
#  activation_88 (Activation)     (None, 63, 63, 256)  0           ['add_30[0][0]']
#
#  res2c_branch2a (Conv2D)        (None, 63, 63, 64)   16448       ['activation_88[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 63, 63, 64)  256         ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_89 (Activation)     (None, 63, 63, 64)   0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv2D)        (None, 63, 63, 64)   36928       ['activation_89[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 63, 63, 64)  256         ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_90 (Activation)     (None, 63, 63, 64)   0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv2D)        (None, 63, 63, 256)  16640       ['activation_90[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 63, 63, 256)  1024       ['res2c_branch2c[0][0]']
#  ion)
#
#  add_31 (Add)                   (None, 63, 63, 256)  0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_88[0][0]']
#
#  activation_91 (Activation)     (None, 63, 63, 256)  0           ['add_31[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 32, 32, 128)  32896       ['activation_91[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 32, 32, 128)  512        ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_92 (Activation)     (None, 32, 32, 128)  0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 32, 32, 128)  147584      ['activation_92[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 32, 32, 128)  512        ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_93 (Activation)     (None, 32, 32, 128)  0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv2D)        (None, 32, 32, 512)  66048       ['activation_93[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 32, 32, 512)  131584      ['activation_91[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 32, 32, 512)  2048       ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 32, 32, 512)  2048       ['res3a_branch1[0][0]']
#  on)
#
#  add_32 (Add)                   (None, 32, 32, 512)  0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_94 (Activation)     (None, 32, 32, 512)  0           ['add_32[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 32, 32, 128)  65664       ['activation_94[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 32, 32, 128)  512        ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_95 (Activation)     (None, 32, 32, 128)  0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 32, 32, 128)  147584      ['activation_95[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 32, 32, 128)  512        ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_96 (Activation)     (None, 32, 32, 128)  0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv2D)        (None, 32, 32, 512)  66048       ['activation_96[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 32, 32, 512)  2048       ['res3b_branch2c[0][0]']
#  ion)
#
#  add_33 (Add)                   (None, 32, 32, 512)  0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_94[0][0]']
#
#  activation_97 (Activation)     (None, 32, 32, 512)  0           ['add_33[0][0]']
#
#  res3c_branch2a (Conv2D)        (None, 32, 32, 128)  65664       ['activation_97[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 32, 32, 128)  512        ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_98 (Activation)     (None, 32, 32, 128)  0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv2D)        (None, 32, 32, 128)  147584      ['activation_98[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 32, 32, 128)  512        ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_99 (Activation)     (None, 32, 32, 128)  0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv2D)        (None, 32, 32, 512)  66048       ['activation_99[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 32, 32, 512)  2048       ['res3c_branch2c[0][0]']
#  ion)
#
#  add_34 (Add)                   (None, 32, 32, 512)  0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_97[0][0]']
#
#  activation_100 (Activation)    (None, 32, 32, 512)  0           ['add_34[0][0]']
#
#  res3d_branch2a (Conv2D)        (None, 32, 32, 128)  65664       ['activation_100[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 32, 32, 128)  512        ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_101 (Activation)    (None, 32, 32, 128)  0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv2D)        (None, 32, 32, 128)  147584      ['activation_101[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 32, 32, 128)  512        ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_102 (Activation)    (None, 32, 32, 128)  0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv2D)        (None, 32, 32, 512)  66048       ['activation_102[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 32, 32, 512)  2048       ['res3d_branch2c[0][0]']
#  ion)
#
#  add_35 (Add)                   (None, 32, 32, 512)  0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_100[0][0]']
#
#  activation_103 (Activation)    (None, 32, 32, 512)  0           ['add_35[0][0]']
#
#  res4a_branch2a (Conv2D)        (None, 16, 16, 256)  131328      ['activation_103[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_104 (Activation)    (None, 16, 16, 256)  0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_104[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_105 (Activation)    (None, 16, 16, 256)  0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_105[0][0]']
#                                 )
#
#  res4a_branch1 (Conv2D)         (None, 16, 16, 1024  525312      ['activation_103[0][0]']
#                                 )
#
#  bn4a_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4a_branch2c[0][0]']
#  ion)                           )
#
#  bn4a_branch1 (BatchNormalizati  (None, 16, 16, 1024  4096       ['res4a_branch1[0][0]']
#  on)                            )
#
#  add_36 (Add)                   (None, 16, 16, 1024  0           ['bn4a_branch2c[0][0]',
#                                 )                                 'bn4a_branch1[0][0]']
#
#  activation_106 (Activation)    (None, 16, 16, 1024  0           ['add_36[0][0]']
#                                 )
#
#  res4b_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_106[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4b_branch2a[0][0]']
#  ion)
#
#  activation_107 (Activation)    (None, 16, 16, 256)  0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_107[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4b_branch2b[0][0]']
#  ion)
#
#  activation_108 (Activation)    (None, 16, 16, 256)  0           ['bn4b_branch2b[0][0]']
#
#  res4b_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_108[0][0]']
#                                 )
#
#  bn4b_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4b_branch2c[0][0]']
#  ion)                           )
#
#  add_37 (Add)                   (None, 16, 16, 1024  0           ['bn4b_branch2c[0][0]',
#                                 )                                 'activation_106[0][0]']
#
#  activation_109 (Activation)    (None, 16, 16, 1024  0           ['add_37[0][0]']
#                                 )
#
#  res4c_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_109[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4c_branch2a[0][0]']
#  ion)
#
#  activation_110 (Activation)    (None, 16, 16, 256)  0           ['bn4c_branch2a[0][0]']
#
#  res4c_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_110[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4c_branch2b[0][0]']
#  ion)
#
#  activation_111 (Activation)    (None, 16, 16, 256)  0           ['bn4c_branch2b[0][0]']
#
#  res4c_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_111[0][0]']
#                                 )
#
#  bn4c_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4c_branch2c[0][0]']
#  ion)                           )
#
#  add_38 (Add)                   (None, 16, 16, 1024  0           ['bn4c_branch2c[0][0]',
#                                 )                                 'activation_109[0][0]']
#
#  activation_112 (Activation)    (None, 16, 16, 1024  0           ['add_38[0][0]']
#                                 )
#
#  res4d_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_112[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4d_branch2a[0][0]']
#  ion)
#
#  activation_113 (Activation)    (None, 16, 16, 256)  0           ['bn4d_branch2a[0][0]']
#
#  res4d_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_113[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4d_branch2b[0][0]']
#  ion)
#
#  activation_114 (Activation)    (None, 16, 16, 256)  0           ['bn4d_branch2b[0][0]']
#
#  res4d_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_114[0][0]']
#                                 )
#
#  bn4d_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4d_branch2c[0][0]']
#  ion)                           )
#
#  add_39 (Add)                   (None, 16, 16, 1024  0           ['bn4d_branch2c[0][0]',
#                                 )                                 'activation_112[0][0]']
#
#  activation_115 (Activation)    (None, 16, 16, 1024  0           ['add_39[0][0]']
#                                 )
#
#  res4e_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_115[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4e_branch2a[0][0]']
#  ion)
#
#  activation_116 (Activation)    (None, 16, 16, 256)  0           ['bn4e_branch2a[0][0]']
#
#  res4e_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_116[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4e_branch2b[0][0]']
#  ion)
#
#  activation_117 (Activation)    (None, 16, 16, 256)  0           ['bn4e_branch2b[0][0]']
#
#  res4e_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_117[0][0]']
#                                 )
#
#  bn4e_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4e_branch2c[0][0]']
#  ion)                           )
#
#  add_40 (Add)                   (None, 16, 16, 1024  0           ['bn4e_branch2c[0][0]',
#                                 )                                 'activation_115[0][0]']
#
#  activation_118 (Activation)    (None, 16, 16, 1024  0           ['add_40[0][0]']
#                                 )
#
#  res4f_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_118[0][0]']
#
#  bn4f_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4f_branch2a[0][0]']
#  ion)
#
#  activation_119 (Activation)    (None, 16, 16, 256)  0           ['bn4f_branch2a[0][0]']
#
#  res4f_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_119[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4f_branch2b[0][0]']
#  ion)
#
#  activation_120 (Activation)    (None, 16, 16, 256)  0           ['bn4f_branch2b[0][0]']
#
#  res4f_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_120[0][0]']
#                                 )
#
#  bn4f_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4f_branch2c[0][0]']
#  ion)                           )
#
#  add_41 (Add)                   (None, 16, 16, 1024  0           ['bn4f_branch2c[0][0]',
#                                 )                                 'activation_118[0][0]']
#
#  activation_121 (Activation)    (None, 16, 16, 1024  0           ['add_41[0][0]']
#                                 )
#
#  res4g_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_121[0][0]']
#
#  bn4g_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4g_branch2a[0][0]']
#  ion)
#
#  activation_122 (Activation)    (None, 16, 16, 256)  0           ['bn4g_branch2a[0][0]']
#
#  res4g_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_122[0][0]']
#
#  bn4g_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4g_branch2b[0][0]']
#  ion)
#
#  activation_123 (Activation)    (None, 16, 16, 256)  0           ['bn4g_branch2b[0][0]']
#
#  res4g_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_123[0][0]']
#                                 )
#
#  bn4g_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4g_branch2c[0][0]']
#  ion)                           )
#
#  add_42 (Add)                   (None, 16, 16, 1024  0           ['bn4g_branch2c[0][0]',
#                                 )                                 'activation_121[0][0]']
#
#  activation_124 (Activation)    (None, 16, 16, 1024  0           ['add_42[0][0]']
#                                 )
#
#  res4h_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_124[0][0]']
#
#  bn4h_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4h_branch2a[0][0]']
#  ion)
#
#  activation_125 (Activation)    (None, 16, 16, 256)  0           ['bn4h_branch2a[0][0]']
#
#  res4h_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_125[0][0]']
#
#  bn4h_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4h_branch2b[0][0]']
#  ion)
#
#  activation_126 (Activation)    (None, 16, 16, 256)  0           ['bn4h_branch2b[0][0]']
#
#  res4h_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_126[0][0]']
#                                 )
#
#  bn4h_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4h_branch2c[0][0]']
#  ion)                           )
#
#  add_43 (Add)                   (None, 16, 16, 1024  0           ['bn4h_branch2c[0][0]',
#                                 )                                 'activation_124[0][0]']
#
#  activation_127 (Activation)    (None, 16, 16, 1024  0           ['add_43[0][0]']
#                                 )
#
#  res4i_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_127[0][0]']
#
#  bn4i_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4i_branch2a[0][0]']
#  ion)
#
#  activation_128 (Activation)    (None, 16, 16, 256)  0           ['bn4i_branch2a[0][0]']
#
#  res4i_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_128[0][0]']
#
#  bn4i_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4i_branch2b[0][0]']
#  ion)
#
#  activation_129 (Activation)    (None, 16, 16, 256)  0           ['bn4i_branch2b[0][0]']
#
#  res4i_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_129[0][0]']
#                                 )
#
#  bn4i_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4i_branch2c[0][0]']
#  ion)                           )
#
#  add_44 (Add)                   (None, 16, 16, 1024  0           ['bn4i_branch2c[0][0]',
#                                 )                                 'activation_127[0][0]']
#
#  activation_130 (Activation)    (None, 16, 16, 1024  0           ['add_44[0][0]']
#                                 )
#
#  res4j_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_130[0][0]']
#
#  bn4j_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4j_branch2a[0][0]']
#  ion)
#
#  activation_131 (Activation)    (None, 16, 16, 256)  0           ['bn4j_branch2a[0][0]']
#
#  res4j_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_131[0][0]']
#
#  bn4j_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4j_branch2b[0][0]']
#  ion)
#
#  activation_132 (Activation)    (None, 16, 16, 256)  0           ['bn4j_branch2b[0][0]']
#
#  res4j_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_132[0][0]']
#                                 )
#
#  bn4j_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4j_branch2c[0][0]']
#  ion)                           )
#
#  add_45 (Add)                   (None, 16, 16, 1024  0           ['bn4j_branch2c[0][0]',
#                                 )                                 'activation_130[0][0]']
#
#  activation_133 (Activation)    (None, 16, 16, 1024  0           ['add_45[0][0]']
#                                 )
#
#  res4k_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_133[0][0]']
#
#  bn4k_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4k_branch2a[0][0]']
#  ion)
#
#  activation_134 (Activation)    (None, 16, 16, 256)  0           ['bn4k_branch2a[0][0]']
#
#  res4k_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_134[0][0]']
#
#  bn4k_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4k_branch2b[0][0]']
#  ion)
#
#  activation_135 (Activation)    (None, 16, 16, 256)  0           ['bn4k_branch2b[0][0]']
#
#  res4k_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_135[0][0]']
#                                 )
#
#  bn4k_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4k_branch2c[0][0]']
#  ion)                           )
#
# ...
#
#  bn4u_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4u_branch2b[0][0]']
#  ion)
#
#  activation_165 (Activation)    (None, 16, 16, 256)  0           ['bn4u_branch2b[0][0]']
#
#  res4u_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_165[0][0]']
#                                 )
#
#  bn4u_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4u_branch2c[0][0]']
#  ion)                           )
#
#  add_56 (Add)                   (None, 16, 16, 1024  0           ['bn4u_branch2c[0][0]',
#                                 )                                 'activation_163[0][0]']
#
#  activation_166 (Activation)    (None, 16, 16, 1024  0           ['add_56[0][0]']
#                                 )
#
#  res4v_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_166[0][0]']
#
#  bn4v_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4v_branch2a[0][0]']
#  ion)
#
#  activation_167 (Activation)    (None, 16, 16, 256)  0           ['bn4v_branch2a[0][0]']
#
#  res4v_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_167[0][0]']
#
#  bn4v_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4v_branch2b[0][0]']
#  ion)
#
#  activation_168 (Activation)    (None, 16, 16, 256)  0           ['bn4v_branch2b[0][0]']
#
#  res4v_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_168[0][0]']
#                                 )
#
#  bn4v_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4v_branch2c[0][0]']
#  ion)                           )
#
#  add_57 (Add)                   (None, 16, 16, 1024  0           ['bn4v_branch2c[0][0]',
#                                 )                                 'activation_166[0][0]']
#
#  activation_169 (Activation)    (None, 16, 16, 1024  0           ['add_57[0][0]']
#                                 )
#
#  res4z_branch2a (Conv2D)        (None, 16, 16, 256)  262400      ['activation_169[0][0]']
#
#  bn4z_branch2a (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4z_branch2a[0][0]']
#  ion)
#
#  activation_170 (Activation)    (None, 16, 16, 256)  0           ['bn4z_branch2a[0][0]']
#
#  res4z_branch2b (Conv2D)        (None, 16, 16, 256)  590080      ['activation_170[0][0]']
#
#  bn4z_branch2b (BatchNormalizat  (None, 16, 16, 256)  1024       ['res4z_branch2b[0][0]']
#  ion)
#
#  activation_171 (Activation)    (None, 16, 16, 256)  0           ['bn4z_branch2b[0][0]']
#
#  res4z_branch2c (Conv2D)        (None, 16, 16, 1024  263168      ['activation_171[0][0]']
#                                 )
#
#  bn4z_branch2c (BatchNormalizat  (None, 16, 16, 1024  4096       ['res4z_branch2c[0][0]']
#  ion)                           )
#
#  add_58 (Add)                   (None, 16, 16, 1024  0           ['bn4z_branch2c[0][0]',
#                                 )                                 'activation_169[0][0]']
#
#  activation_172 (Activation)    (None, 16, 16, 1024  0           ['add_58[0][0]']
#                                 )
#
#  res5a_branch2a (Conv2D)        (None, 8, 8, 512)    524800      ['activation_172[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 8, 8, 512)   2048        ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_173 (Activation)    (None, 8, 8, 512)    0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)        (None, 8, 8, 512)    2359808     ['activation_173[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 8, 8, 512)   2048        ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_174 (Activation)    (None, 8, 8, 512)    0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv2D)        (None, 8, 8, 2048)   1050624     ['activation_174[0][0]']
#
#  res5a_branch1 (Conv2D)         (None, 8, 8, 2048)   2099200     ['activation_172[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 8, 8, 2048)  8192        ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 8, 8, 2048)  8192        ['res5a_branch1[0][0]']
#  on)
#
#  add_59 (Add)                   (None, 8, 8, 2048)   0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_175 (Activation)    (None, 8, 8, 2048)   0           ['add_59[0][0]']
#
#  res5b_branch2a (Conv2D)        (None, 8, 8, 512)    1049088     ['activation_175[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 8, 8, 512)   2048        ['res5b_branch2a[0][0]']
#  ion)
#
#  activation_176 (Activation)    (None, 8, 8, 512)    0           ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)        (None, 8, 8, 512)    2359808     ['activation_176[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 8, 8, 512)   2048        ['res5b_branch2b[0][0]']
#  ion)
#
#  activation_177 (Activation)    (None, 8, 8, 512)    0           ['bn5b_branch2b[0][0]']
#
#  res5b_branch2c (Conv2D)        (None, 8, 8, 2048)   1050624     ['activation_177[0][0]']
#
#  bn5b_branch2c (BatchNormalizat  (None, 8, 8, 2048)  8192        ['res5b_branch2c[0][0]']
#  ion)
#
#  add_60 (Add)                   (None, 8, 8, 2048)   0           ['bn5b_branch2c[0][0]',
#                                                                   'activation_175[0][0]']
#
#  activation_178 (Activation)    (None, 8, 8, 2048)   0           ['add_60[0][0]']
#
#  res5c_branch2a (Conv2D)        (None, 8, 8, 512)    1049088     ['activation_178[0][0]']
#
#  bn5c_branch2a (BatchNormalizat  (None, 8, 8, 512)   2048        ['res5c_branch2a[0][0]']
#  ion)
#
#  activation_179 (Activation)    (None, 8, 8, 512)    0           ['bn5c_branch2a[0][0]']
#
#  res5c_branch2b (Conv2D)        (None, 8, 8, 512)    2359808     ['activation_179[0][0]']
#
#  bn5c_branch2b (BatchNormalizat  (None, 8, 8, 512)   2048        ['res5c_branch2b[0][0]']
#  ion)
#
#  activation_180 (Activation)    (None, 8, 8, 512)    0           ['bn5c_branch2b[0][0]']
#
#  res5c_branch2c (Conv2D)        (None, 8, 8, 2048)   1050624     ['activation_180[0][0]']
#
#  bn5c_branch2c (BatchNormalizat  (None, 8, 8, 2048)  8192        ['res5c_branch2c[0][0]']
#  ion)
#
#  add_61 (Add)                   (None, 8, 8, 2048)   0           ['bn5c_branch2c[0][0]',
#                                                                   'activation_178[0][0]']
#
#  activation_181 (Activation)    (None, 8, 8, 2048)   0           ['add_61[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 4, 4, 2048)  0           ['activation_181[0][0]']
#  oling2D)
#
#  flatten_2 (Flatten)            (None, 32768)        0           ['average_pooling2d_2[0][0]']
#
#  dense_4 (Dense)                (None, 125)          4096125     ['flatten_2[0][0]']
#
#  dense_5 (Dense)                (None, 65536)        8257536     ['dense_4[0][0]']
#
#  tf.reshape_2 (TFOpLambda)      (None, 256, 256, 1)  0           ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 55,011,837
# Trainable params: 54,906,493
# Non-trainable params: 105,344
# __________________________________________________________________________________________________

# %%
resnet_train_v2 = resnet_model_v2.fit(train_gen_small,
                                      validation_data=val_gen_small,
                                      epochs = EPOCHS,
                                      steps_per_epoch = STEPS_PER_EPOCH_small,
                                      validation_steps = VALIDATION_STEPS_small,
                                      verbose = True)
# Out:
# Epoch 1/25
# 563/563 [==============================] - 100s 160ms/step - loss: 1.9679 - accuracy: 0.8188 - val_loss: 2.0531 - val_accuracy: 0.8100
# Epoch 2/25
# 563/563 [==============================] - 89s 159ms/step - loss: 1.9581 - accuracy: 0.8188 - val_loss: 2.0636 - val_accuracy: 0.8091
# Epoch 3/25
# 563/563 [==============================] - 89s 157ms/step - loss: 1.9555 - accuracy: 0.8190 - val_loss: 2.0488 - val_accuracy: 0.8104
# Epoch 4/25
# 563/563 [==============================] - 88s 156ms/step - loss: 1.9542 - accuracy: 0.8191 - val_loss: 2.0553 - val_accuracy: 0.8098
# Epoch 5/25
# 563/563 [==============================] - 88s 156ms/step - loss: 1.9517 - accuracy: 0.8193 - val_loss: 2.0489 - val_accuracy: 0.8105
# Epoch 6/25
# 563/563 [==============================] - 88s 157ms/step - loss: 1.9575 - accuracy: 0.8188 - val_loss: 2.0662 - val_accuracy: 0.8087
# Epoch 7/25
# 563/563 [==============================] - 88s 156ms/step - loss: 1.9545 - accuracy: 0.8190 - val_loss: 2.0195 - val_accuracy: 0.8131
# Epoch 8/25
# 563/563 [==============================] - 88s 156ms/step - loss: 1.9562 - accuracy: 0.8189 - val_loss: 2.0296 - val_accuracy: 0.8120
# Epoch 9/25
# 563/563 [==============================] - 88s 156ms/step - loss: 1.9469 - accuracy: 0.8197 - val_loss: 2.0510 - val_accuracy: 0.8103
# Epoch 10/25
# 563/563 [==============================] - 88s 156ms/step - loss: 1.9591 - accuracy: 0.8186 - val_loss: 2.1028 - val_accuracy: 0.8055
# Epoch 11/25
# 563/563 [==============================] - 88s 157ms/step - loss: 1.9512 - accuracy: 0.8192 - val_loss: 2.0141 - val_accuracy: 0.8133
# Epoch 12/25
# 563/563 [==============================] - 88s 156ms/step - loss: 1.9549 - accuracy: 0.8188 - val_loss: 2.0614 - val_accuracy: 0.8091
# Epoch 13/25
# 563/563 [==============================] - 88s 157ms/step - loss: 1.9493 - accuracy: 0.8192 - val_loss: 2.0528 - val_accuracy: 0.8097
# Epoch 14/25
# 563/563 [==============================] - 88s 156ms/step - loss: 1.9580 - accuracy: 0.8184 - val_loss: 2.0088 - val_accuracy: 0.8135
# Epoch 15/25
# 563/563 [==============================] - 88s 156ms/step - loss: 1.9472 - accuracy: 0.8192 - val_loss: 2.0602 - val_accuracy: 0.8088
# Epoch 16/25
# 563/563 [==============================] - 88s 156ms/step - loss: 1.9565 - accuracy: 0.8182 - val_loss: 2.0706 - val_accuracy: 0.8078
# Epoch 17/25
# 563/563 [==============================] - 88s 157ms/step - loss: 1.9377 - accuracy: 0.8198 - val_loss: 2.0284 - val_accuracy: 0.8115
# Epoch 18/25
# 563/563 [==============================] - 88s 157ms/step - loss: 1.9483 - accuracy: 0.8187 - val_loss: 2.0354 - val_accuracy: 0.8108
# Epoch 19/25
# 563/563 [==============================] - 88s 156ms/step - loss: 1.9512 - accuracy: 0.8183 - val_loss: 2.0007 - val_accuracy: 0.8139
# Epoch 20/25
# 563/563 [==============================] - 88s 157ms/step - loss: 1.9339 - accuracy: 0.8198 - val_loss: 2.0567 - val_accuracy: 0.8087
# Epoch 21/25
# 563/563 [==============================] - 88s 156ms/step - loss: 1.9400 - accuracy: 0.8191 - val_loss: 2.0438 - val_accuracy: 0.8097
# Epoch 22/25
# 563/563 [==============================] - 89s 158ms/step - loss: 1.9419 - accuracy: 0.8188 - val_loss: 1.9839 - val_accuracy: 0.8151
# Epoch 23/25
# 563/563 [==============================] - 90s 159ms/step - loss: 1.9417 - accuracy: 0.8187 - val_loss: 2.0776 - val_accuracy: 0.8065
# Epoch 24/25
# 563/563 [==============================] - 91s 161ms/step - loss: 1.9344 - accuracy: 0.8192 - val_loss: 2.0345 - val_accuracy: 0.8105
# Epoch 25/25
# 563/563 [==============================] - 87s 155ms/step - loss: 1.9328 - accuracy: 0.8192 - val_loss: 2.0481 - val_accuracy: 0.8096

# %%
resnet_model_v2.save('resnet_v2')
# Out:
# [WARNING] save:__init__:233 - Found untraced functions such as %s while saving (showing %d of %d). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 104). These functions will not be directly callable after loading.
# [INFO   ] builder_impl:copy_assets_to_destination_dir:779 - Assets written to: %s
# INFO:tensorflow:Assets written to: resnet_v2\assets
# INFO:tensorflow:Assets written to: resnet_v2\assets

# %% [markdown]
# # U-Net version 1

# %%
def UNetModel_v1(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES):
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    x = inputs
    
    # Encoder part - contraction
    c1 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(x)
    d1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(d1)
    p1 = MaxPooling2D(pool_size = (2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(p1)
    d2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(d2)
    p2 = MaxPooling2D(pool_size = (2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(p2)
    d3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d3)
    p3 = MaxPooling2D(pool_size = (2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(p3)
    d4 = Dropout(0.2)(c4)    
    c4 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d4)
    p4 = MaxPooling2D(pool_size = (2, 2))(c4)
    
    ## Bottleneck part - bottom
    c5 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(p4)
    d5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d5)
    
    # Decoder part - expansion
    u6 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c5))
    u6 = concatenate([u6, c4], axis = 3)
    c6 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(u6)
    d6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d6)

    u7 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c6))
    u7 = concatenate([u7, c3], axis = 3)
    c7 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(u7)
    d7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d7)

    u8 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c7))
    u8 = concatenate([u8, c2], axis = 3)
    c8 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(u8)
    d8 = Dropout(0.1)(c8)
    c8 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(d8)

    u9 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c8))
    u9 = concatenate([u9, c1], axis = 3)
    c9 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(u9)
    d9 = Dropout(0.1)(c9)
    c9 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(d9)

    outputs = Conv2D(N_CLASSES, (1, 1), activation = 'sigmoid')(c9)
    
    model = Model(inputs, outputs, name = 'U-Net_v1')
    
    return model

# %%
unet_model_v1 = UNetModel_v1(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES)
unet_model_v1.compile(optimizer = OPTIMIZER (learning_rate = LEARNING_RATE), 
                      loss = LOSS, 
                      metrics = METRICS)
unet_model_v1.summary()
# Out:
# Model: "U-Net_v1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 16  448         ['input_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 256, 256, 16  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  2320        ['dropout[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 16  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  4640        ['max_pooling2d[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 128, 128, 32  0           ['conv2d_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  9248        ['dropout_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 64, 64, 64)   0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 64)   36928       ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 32, 32, 128)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 128)  147584      ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 256)  0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 256)  590080      ['dropout_4[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 256)  0           ['conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 128)  295040      ['up_sampling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 256)  0           ['conv2d_10[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 128)  0           ['conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_5[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 128)  0          ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 64)   73792       ['up_sampling2d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_13[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 64)   0           ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_6[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 64  0          ['conv2d_15[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 32  18464       ['up_sampling2d_2[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_16[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  dropout_7 (Dropout)            (None, 128, 128, 32  0           ['conv2d_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_7[0][0]']
#                                 )
#
#  up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 32  0          ['conv2d_18[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 16  4624        ['up_sampling2d_3[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 32  0           ['conv2d_19[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 256, 256, 16  0           ['conv2d_20[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 256, 256, 16  2320        ['dropout_8[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 256, 256, 1)  17          ['conv2d_21[0][0]']
#
# ==================================================================================================
# Total params: 2,158,705
# Trainable params: 2,158,705
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
unet_train_v1 = unet_model_v1.fit(train_gen,
                                  validation_data=val_gen,
                                  epochs = EPOCHS,
                                  steps_per_epoch = STEPS_PER_EPOCH,
                                  validation_steps = VALIDATION_STEPS,
                                  verbose = True)
# Out:
# Epoch 1/25
# 281/281 [==============================] - 57s 177ms/step - loss: 0.4458 - accuracy: 0.8185 - val_loss: 0.4065 - val_accuracy: 0.8099
# Epoch 2/25
# 281/281 [==============================] - 42s 151ms/step - loss: 0.4045 - accuracy: 0.8202 - val_loss: 0.4078 - val_accuracy: 0.8211
# Epoch 3/25
# 281/281 [==============================] - 43s 152ms/step - loss: 0.3972 - accuracy: 0.8260 - val_loss: 0.4029 - val_accuracy: 0.8193
# Epoch 4/25
# 281/281 [==============================] - 43s 152ms/step - loss: 0.3948 - accuracy: 0.8274 - val_loss: 0.4345 - val_accuracy: 0.8039
# Epoch 5/25
# 281/281 [==============================] - 42s 151ms/step - loss: 0.3925 - accuracy: 0.8293 - val_loss: 0.4052 - val_accuracy: 0.8228
# Epoch 6/25
# 281/281 [==============================] - 42s 151ms/step - loss: 0.3897 - accuracy: 0.8294 - val_loss: 0.3942 - val_accuracy: 0.8260
# Epoch 7/25
# 281/281 [==============================] - 43s 152ms/step - loss: 0.3863 - accuracy: 0.8319 - val_loss: 0.3860 - val_accuracy: 0.8308
# Epoch 8/25
# 281/281 [==============================] - 43s 152ms/step - loss: 0.3689 - accuracy: 0.8402 - val_loss: 0.3690 - val_accuracy: 0.8393
# Epoch 9/25
# 281/281 [==============================] - 43s 153ms/step - loss: 0.3547 - accuracy: 0.8471 - val_loss: 0.3437 - val_accuracy: 0.8490
# Epoch 10/25
# 281/281 [==============================] - 42s 151ms/step - loss: 0.3417 - accuracy: 0.8540 - val_loss: 0.3378 - val_accuracy: 0.8474
# Epoch 11/25
# 281/281 [==============================] - 42s 151ms/step - loss: 0.3256 - accuracy: 0.8589 - val_loss: 0.3107 - val_accuracy: 0.8666
# Epoch 12/25
# 281/281 [==============================] - 43s 151ms/step - loss: 0.3150 - accuracy: 0.8650 - val_loss: 0.2927 - val_accuracy: 0.8733
# Epoch 13/25
# 281/281 [==============================] - 42s 150ms/step - loss: 0.2964 - accuracy: 0.8737 - val_loss: 0.3097 - val_accuracy: 0.8676
# Epoch 14/25
# 281/281 [==============================] - 42s 150ms/step - loss: 0.2868 - accuracy: 0.8783 - val_loss: 0.2788 - val_accuracy: 0.8792
# Epoch 15/25
# 281/281 [==============================] - 42s 150ms/step - loss: 0.2737 - accuracy: 0.8836 - val_loss: 0.2859 - val_accuracy: 0.8762
# Epoch 16/25
# 281/281 [==============================] - 42s 150ms/step - loss: 0.2697 - accuracy: 0.8854 - val_loss: 0.2687 - val_accuracy: 0.8864
# Epoch 17/25
# 281/281 [==============================] - 42s 151ms/step - loss: 0.2588 - accuracy: 0.8901 - val_loss: 0.2689 - val_accuracy: 0.8848
# Epoch 18/25
# 281/281 [==============================] - 43s 151ms/step - loss: 0.2515 - accuracy: 0.8938 - val_loss: 0.2471 - val_accuracy: 0.8952
# Epoch 19/25
# 281/281 [==============================] - 42s 151ms/step - loss: 0.2383 - accuracy: 0.9001 - val_loss: 0.2726 - val_accuracy: 0.8832
# Epoch 20/25
# 281/281 [==============================] - 42s 151ms/step - loss: 0.2373 - accuracy: 0.9006 - val_loss: 0.2720 - val_accuracy: 0.8920
# Epoch 21/25
# 281/281 [==============================] - 42s 151ms/step - loss: 0.2291 - accuracy: 0.9052 - val_loss: 0.2533 - val_accuracy: 0.8898
# Epoch 22/25
# 281/281 [==============================] - 42s 150ms/step - loss: 0.2212 - accuracy: 0.9083 - val_loss: 0.2399 - val_accuracy: 0.9006
# Epoch 23/25
# 281/281 [==============================] - 42s 151ms/step - loss: 0.2131 - accuracy: 0.9118 - val_loss: 0.2369 - val_accuracy: 0.9020
# Epoch 24/25
# 281/281 [==============================] - 42s 151ms/step - loss: 0.2061 - accuracy: 0.9144 - val_loss: 0.2338 - val_accuracy: 0.9017
# Epoch 25/25
# 281/281 [==============================] - 43s 152ms/step - loss: 0.1990 - accuracy: 0.9187 - val_loss: 0.2347 - val_accuracy: 0.9021

# %%
unet_model_v1.save('unet_v1')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 23). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: unet_v1\assets
# INFO:tensorflow:Assets written to: unet_v1\assets

# %% [markdown]
# # U-Net version 2

# %%
def UNetModel_v2(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES):
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    x = inputs
    
    # Encoder part - contraction
    c1 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(x)
    d1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(d1)
    p1 = MaxPooling2D(pool_size = (2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(p1)
    d2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(d2)
    p2 = MaxPooling2D(pool_size = (2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(p2)
    d3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d3)
    p3 = MaxPooling2D(pool_size = (2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(p3)
    d4 = Dropout(0.2)(c4)    
    c4 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d4)
    p4 = MaxPooling2D(pool_size = (2, 2))(c4)
    
    c5 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(p4)
    d5 = Dropout(0.3)(c5)    
    c5 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d5)
    p5 = MaxPooling2D(pool_size = (2, 2))(c5)
    
    c6 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(p5)
    d6 = Dropout(0.3)(c6)    
    c6 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d6)
    p6 = MaxPooling2D(pool_size = (2, 2))(c6)
    
    ## Bottleneck part - bottom
    c7 = Conv2D(1024, (3, 3), activation = 'relu', padding = 'same')(p6)
    d7 = Dropout(0.4)(c7)
    c7 = Conv2D(1024, (3, 3), activation = 'relu', padding = 'same')(d7)
    
    # Decoder part - expansion
    u8 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c7))
    u8 = concatenate([u8, c6], axis = 3)
    c8 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(u8)
    d8 = Dropout(0.3)(c8)
    c8 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d8)

    u9 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c8))
    u9 = concatenate([u9, c5], axis = 3)
    c9 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(u9)
    d9 = Dropout(0.3)(c9)
    c9 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d9)

    u10 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c9))
    u10 = concatenate([u10, c4], axis = 3)
    c10 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(u10)
    d10 = Dropout(0.2)(c10)
    c10 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d10)

    u11 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c10))
    u11 = concatenate([u11, c3], axis = 3)
    c11 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(u11)
    d11 = Dropout(0.2)(c11)
    c11 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d11)
    
    u12 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c11))
    u12 = concatenate([u12, c2], axis = 3)
    c12 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(u12)
    d12 = Dropout(0.1)(c12)
    c12 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(d12)
    
    u13 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c12))
    u13 = concatenate([u13, c1], axis = 3)
    c13 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(u13)
    d13 = Dropout(0.1)(c13)
    c13 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(d13)

    outputs = Conv2D(N_CLASSES, (1, 1), activation = 'sigmoid')(c13)
    
    model = Model(inputs, outputs, name = 'U-Net_v2')
    
    return model

# %%
unet_model_v2 = UNetModel_v2(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES)
unet_model_v2.compile(optimizer = OPTIMIZER (learning_rate = LEARNING_RATE), 
                      loss = LOSS, 
                      metrics = METRICS)
unet_model_v2.summary()
# Out:
# Model: "U-Net_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_23 (Conv2D)             (None, 256, 256, 16  448         ['input_2[0][0]']
#                                 )
#
#  dropout_9 (Dropout)            (None, 256, 256, 16  0           ['conv2d_23[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 256, 256, 16  2320        ['dropout_9[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 16  0          ['conv2d_24[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 32  4640        ['max_pooling2d_4[0][0]']
#                                 )
#
#  dropout_10 (Dropout)           (None, 128, 128, 32  0           ['conv2d_25[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_10[0][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 32)  0           ['conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 64)   18496       ['max_pooling2d_5[0][0]']
#
#  dropout_11 (Dropout)           (None, 64, 64, 64)   0           ['conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_11[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv2d_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 128)  73856       ['max_pooling2d_6[0][0]']
#
#  dropout_12 (Dropout)           (None, 32, 32, 128)  0           ['conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_12[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 256)  295168      ['max_pooling2d_7[0][0]']
#
#  dropout_13 (Dropout)           (None, 16, 16, 256)  0           ['conv2d_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 256)  590080      ['dropout_13[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 8, 8, 256)   0           ['conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 512)    1180160     ['max_pooling2d_8[0][0]']
#
#  dropout_14 (Dropout)           (None, 8, 8, 512)    0           ['conv2d_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 8, 8, 512)    2359808     ['dropout_14[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 4, 4, 512)   0           ['conv2d_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 4, 4, 1024)   4719616     ['max_pooling2d_9[0][0]']
#
#  dropout_15 (Dropout)           (None, 4, 4, 1024)   0           ['conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 4, 4, 1024)   9438208     ['dropout_15[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 8, 8, 1024)  0           ['conv2d_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 8, 8, 512)    4719104     ['up_sampling2d_4[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 8, 8, 1024)   0           ['conv2d_37[0][0]',
#                                                                   'conv2d_34[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 512)    4719104     ['concatenate_4[0][0]']
#
#  dropout_16 (Dropout)           (None, 8, 8, 512)    0           ['conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 512)    2359808     ['dropout_16[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 16, 16, 512)  0          ['conv2d_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 16, 16, 256)  1179904     ['up_sampling2d_5[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 16, 16, 512)  0           ['conv2d_40[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 16, 16, 256)  1179904     ['concatenate_5[0][0]']
#
#  dropout_17 (Dropout)           (None, 16, 16, 256)  0           ['conv2d_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 256)  590080      ['dropout_17[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 32, 32, 256)  0          ['conv2d_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 32, 32, 128)  295040      ['up_sampling2d_6[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 32, 32, 256)  0           ['conv2d_43[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_6[0][0]']
#
#  dropout_18 (Dropout)           (None, 32, 32, 128)  0           ['conv2d_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_18[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 64, 64, 128)  0          ['conv2d_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 64, 64, 64)   73792       ['up_sampling2d_7[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_46[0][0]',
#                                                                   'conv2d_28[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_7[0][0]']
#
#  dropout_19 (Dropout)           (None, 64, 64, 64)   0           ['conv2d_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_19[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 128, 128, 64  0          ['conv2d_48[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 128, 128, 32  18464       ['up_sampling2d_8[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_49[0][0]',
#                                 )                                 'conv2d_26[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_8[0][0]']
#                                 )
#
#  dropout_20 (Dropout)           (None, 128, 128, 32  0           ['conv2d_50[0][0]']
#                                 )
#
#  conv2d_51 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_20[0][0]']
#                                 )
#
#  up_sampling2d_9 (UpSampling2D)  (None, 256, 256, 32  0          ['conv2d_51[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 256, 256, 16  4624        ['up_sampling2d_9[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 256, 256, 32  0           ['conv2d_52[0][0]',
#                                 )                                 'conv2d_24[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 256, 256, 16  4624        ['concatenate_9[0][0]']
#                                 )
#
#  dropout_21 (Dropout)           (None, 256, 256, 16  0           ['conv2d_53[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 256, 256, 16  2320        ['dropout_21[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 256, 256, 1)  17          ['conv2d_54[0][0]']
#
# ==================================================================================================
# Total params: 34,604,401
# Trainable params: 34,604,401
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
unet_train_v2 = unet_model_v2.fit(train_gen,
                                  validation_data=val_gen,
                                  epochs = EPOCHS,
                                  steps_per_epoch = STEPS_PER_EPOCH,
                                  validation_steps = VALIDATION_STEPS,
                                  verbose = True)
# Out:
# Epoch 1/25
# 281/281 [==============================] - 58s 190ms/step - loss: 1.2979 - accuracy: 0.8192 - val_loss: 0.5085 - val_accuracy: 0.8090
# Epoch 2/25
# 281/281 [==============================] - 54s 193ms/step - loss: 0.4158 - accuracy: 0.8192 - val_loss: 0.4066 - val_accuracy: 0.8228
# Epoch 3/25
# 281/281 [==============================] - 54s 191ms/step - loss: 0.3910 - accuracy: 0.8258 - val_loss: 0.3993 - val_accuracy: 0.8213
# Epoch 4/25
# 281/281 [==============================] - 54s 192ms/step - loss: 0.3797 - accuracy: 0.8319 - val_loss: 0.4288 - val_accuracy: 0.8225
# Epoch 5/25
# 281/281 [==============================] - 54s 192ms/step - loss: 0.3707 - accuracy: 0.8356 - val_loss: 0.3675 - val_accuracy: 0.8355
# Epoch 6/25
# 281/281 [==============================] - 54s 193ms/step - loss: 0.3557 - accuracy: 0.8429 - val_loss: 0.3632 - val_accuracy: 0.8372
# Epoch 7/25
# 281/281 [==============================] - 53s 190ms/step - loss: 0.3502 - accuracy: 0.8463 - val_loss: 0.3611 - val_accuracy: 0.8366
# Epoch 8/25
# 281/281 [==============================] - 53s 190ms/step - loss: 0.3422 - accuracy: 0.8494 - val_loss: 0.3304 - val_accuracy: 0.8531
# Epoch 9/25
# 281/281 [==============================] - 54s 191ms/step - loss: 0.3281 - accuracy: 0.8571 - val_loss: 0.3239 - val_accuracy: 0.8574
# Epoch 10/25
# 281/281 [==============================] - 54s 191ms/step - loss: 0.3206 - accuracy: 0.8599 - val_loss: 0.3214 - val_accuracy: 0.8621
# Epoch 11/25
# 281/281 [==============================] - 53s 190ms/step - loss: 0.3113 - accuracy: 0.8634 - val_loss: 0.3137 - val_accuracy: 0.8599
# Epoch 12/25
# 281/281 [==============================] - 54s 192ms/step - loss: 0.3049 - accuracy: 0.8678 - val_loss: 0.2937 - val_accuracy: 0.8708
# Epoch 13/25
# 281/281 [==============================] - 54s 192ms/step - loss: 0.2991 - accuracy: 0.8710 - val_loss: 0.3318 - val_accuracy: 0.8587
# Epoch 14/25
# 281/281 [==============================] - 53s 190ms/step - loss: 0.2934 - accuracy: 0.8749 - val_loss: 0.2992 - val_accuracy: 0.8691
# Epoch 15/25
# 281/281 [==============================] - 54s 191ms/step - loss: 0.2821 - accuracy: 0.8796 - val_loss: 0.2944 - val_accuracy: 0.8729
# Epoch 16/25
# 281/281 [==============================] - 53s 190ms/step - loss: 0.2760 - accuracy: 0.8830 - val_loss: 0.2911 - val_accuracy: 0.8798
# Epoch 17/25
# 281/281 [==============================] - 53s 190ms/step - loss: 0.2699 - accuracy: 0.8853 - val_loss: 0.2814 - val_accuracy: 0.8775
# Epoch 18/25
# 281/281 [==============================] - 54s 191ms/step - loss: 0.2645 - accuracy: 0.8881 - val_loss: 0.2581 - val_accuracy: 0.8919
# Epoch 19/25
# 281/281 [==============================] - 53s 190ms/step - loss: 0.2583 - accuracy: 0.8919 - val_loss: 0.2630 - val_accuracy: 0.8928
# Epoch 20/25
# 281/281 [==============================] - 53s 190ms/step - loss: 0.2480 - accuracy: 0.8953 - val_loss: 0.2610 - val_accuracy: 0.8938
# Epoch 21/25
# 281/281 [==============================] - 54s 191ms/step - loss: 0.2417 - accuracy: 0.8993 - val_loss: 0.2459 - val_accuracy: 0.8961
# Epoch 22/25
# 281/281 [==============================] - 53s 191ms/step - loss: 0.2363 - accuracy: 0.9024 - val_loss: 0.2425 - val_accuracy: 0.9002
# Epoch 23/25
# 281/281 [==============================] - 54s 191ms/step - loss: 0.2373 - accuracy: 0.9013 - val_loss: 0.2618 - val_accuracy: 0.8881
# Epoch 24/25
# 281/281 [==============================] - 54s 191ms/step - loss: 0.2271 - accuracy: 0.9062 - val_loss: 0.2393 - val_accuracy: 0.8996
# Epoch 25/25
# 281/281 [==============================] - 54s 192ms/step - loss: 0.2223 - accuracy: 0.9071 - val_loss: 0.2219 - val_accuracy: 0.9073

# %%
unet_model_v2.save('unet_v2')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 33). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: unet_v2\assets
# INFO:tensorflow:Assets written to: unet_v2\assets

# %% [markdown]
# # U-Net version 3

# %%
def UNetModel_v3(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES):
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    x = inputs
    
    # Encoder part - contraction
    c1 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(x)
    d1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(d1)
    d1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(d1)
    p1 = MaxPooling2D(pool_size = (2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(p1)
    d2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(d2)
    d2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(d2)
    p2 = MaxPooling2D(pool_size = (2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(p2)
    d3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d3)
    d3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d3)
    p3 = MaxPooling2D(pool_size = (2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(p3)
    d4 = Dropout(0.2)(c4)    
    c4 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d4)
    d4 = Dropout(0.2)(c4)    
    c4 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d4)
    p4 = MaxPooling2D(pool_size = (2, 2))(c4)
    
    c5 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(p4)
    d5 = Dropout(0.3)(c5)    
    c5 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d5)
    d5 = Dropout(0.3)(c5)    
    c5 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d5)
    p5 = MaxPooling2D(pool_size = (2, 2))(c5)
    
    c6 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(p5)
    d6 = Dropout(0.3)(c6)    
    c6 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d6)
    d6 = Dropout(0.3)(c6)    
    c6 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d6)
    p6 = MaxPooling2D(pool_size = (2, 2))(c6)
    
    ## Bottleneck part - bottom
    c7 = Conv2D(1024, (3, 3), activation = 'relu', padding = 'same')(p6)
    d7 = Dropout(0.4)(c7)
    c7 = Conv2D(1024, (3, 3), activation = 'relu', padding = 'same')(d7)
    d7 = Dropout(0.4)(c7)
    c7 = Conv2D(1024, (3, 3), activation = 'relu', padding = 'same')(d7)
    
    # Decoder part - expansion
    u8 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c7))
    u8 = concatenate([u8, c6], axis = 3)
    c8 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(u8)
    d8 = Dropout(0.3)(c8)
    c8 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d8)
    d8 = Dropout(0.3)(c8)
    c8 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d8)

    u9 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c8))
    u9 = concatenate([u9, c5], axis = 3)
    c9 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(u9)
    d9 = Dropout(0.3)(c9)
    c9 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d9)
    d9 = Dropout(0.3)(c9)
    c9 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d9)

    u10 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c9))
    u10 = concatenate([u10, c4], axis = 3)
    c10 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(u10)
    d10 = Dropout(0.2)(c10)
    c10 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d10)
    d10 = Dropout(0.2)(c10)
    c10 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d10)

    u11 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c10))
    u11 = concatenate([u11, c3], axis = 3)
    c11 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(u11)
    d11 = Dropout(0.2)(c11)
    c11 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d11)
    d11 = Dropout(0.2)(c11)
    c11 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d11)
    
    u12 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c11))
    u12 = concatenate([u12, c2], axis = 3)
    c12 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(u12)
    d12 = Dropout(0.1)(c12)
    c12 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(d12)
    d12 = Dropout(0.1)(c12)
    c12 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(d12)
    
    u13 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c12))
    u13 = concatenate([u13, c1], axis = 3)
    c13 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(u13)
    d13 = Dropout(0.1)(c13)
    c13 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(d13)
    d13 = Dropout(0.1)(c13)
    c13 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(d13)

    outputs = Conv2D(N_CLASSES, (1, 1), activation = 'sigmoid')(c13)
    
    model = Model(inputs, outputs, name = 'U-Net_v3')
    
    return model

# %%
unet_model_v3 = UNetModel_v3(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES)
unet_model_v3.compile(optimizer = OPTIMIZER (learning_rate = LEARNING_RATE), 
                      loss = LOSS, 
                      metrics = METRICS)
unet_model_v3.summary()
# Out:
# Model: "U-Net_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_56 (Conv2D)             (None, 256, 256, 16  448         ['input_3[0][0]']
#                                 )
#
#  dropout_22 (Dropout)           (None, 256, 256, 16  0           ['conv2d_56[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 256, 256, 16  2320        ['dropout_22[0][0]']
#                                 )
#
#  dropout_23 (Dropout)           (None, 256, 256, 16  0           ['conv2d_57[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 256, 256, 16  2320        ['dropout_23[0][0]']
#                                 )
#
#  max_pooling2d_10 (MaxPooling2D  (None, 128, 128, 16  0          ['conv2d_58[0][0]']
#  )                              )
#
#  conv2d_59 (Conv2D)             (None, 128, 128, 32  4640        ['max_pooling2d_10[0][0]']
#                                 )
#
#  dropout_24 (Dropout)           (None, 128, 128, 32  0           ['conv2d_59[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_24[0][0]']
#                                 )
#
#  dropout_25 (Dropout)           (None, 128, 128, 32  0           ['conv2d_60[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_25[0][0]']
#                                 )
#
#  max_pooling2d_11 (MaxPooling2D  (None, 64, 64, 32)  0           ['conv2d_61[0][0]']
#  )
#
#  conv2d_62 (Conv2D)             (None, 64, 64, 64)   18496       ['max_pooling2d_11[0][0]']
#
#  dropout_26 (Dropout)           (None, 64, 64, 64)   0           ['conv2d_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_26[0][0]']
#
#  dropout_27 (Dropout)           (None, 64, 64, 64)   0           ['conv2d_63[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_27[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 32, 32, 64)  0           ['conv2d_64[0][0]']
#  )
#
#  conv2d_65 (Conv2D)             (None, 32, 32, 128)  73856       ['max_pooling2d_12[0][0]']
#
#  dropout_28 (Dropout)           (None, 32, 32, 128)  0           ['conv2d_65[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_28[0][0]']
#
#  dropout_29 (Dropout)           (None, 32, 32, 128)  0           ['conv2d_66[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_29[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 16, 16, 128)  0          ['conv2d_67[0][0]']
#  )
#
#  conv2d_68 (Conv2D)             (None, 16, 16, 256)  295168      ['max_pooling2d_13[0][0]']
#
#  dropout_30 (Dropout)           (None, 16, 16, 256)  0           ['conv2d_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 16, 16, 256)  590080      ['dropout_30[0][0]']
#
#  dropout_31 (Dropout)           (None, 16, 16, 256)  0           ['conv2d_69[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 16, 16, 256)  590080      ['dropout_31[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 8, 8, 256)   0           ['conv2d_70[0][0]']
#  )
#
#  conv2d_71 (Conv2D)             (None, 8, 8, 512)    1180160     ['max_pooling2d_14[0][0]']
#
#  dropout_32 (Dropout)           (None, 8, 8, 512)    0           ['conv2d_71[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 8, 8, 512)    2359808     ['dropout_32[0][0]']
#
#  dropout_33 (Dropout)           (None, 8, 8, 512)    0           ['conv2d_72[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 8, 8, 512)    2359808     ['dropout_33[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 4, 4, 512)   0           ['conv2d_73[0][0]']
#  )
#
#  conv2d_74 (Conv2D)             (None, 4, 4, 1024)   4719616     ['max_pooling2d_15[0][0]']
#
#  dropout_34 (Dropout)           (None, 4, 4, 1024)   0           ['conv2d_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 4, 4, 1024)   9438208     ['dropout_34[0][0]']
#
#  dropout_35 (Dropout)           (None, 4, 4, 1024)   0           ['conv2d_75[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 4, 4, 1024)   9438208     ['dropout_35[0][0]']
#
#  up_sampling2d_10 (UpSampling2D  (None, 8, 8, 1024)  0           ['conv2d_76[0][0]']
#  )
#
#  conv2d_77 (Conv2D)             (None, 8, 8, 512)    4719104     ['up_sampling2d_10[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 8, 8, 1024)   0           ['conv2d_77[0][0]',
#                                                                   'conv2d_73[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 8, 8, 512)    4719104     ['concatenate_10[0][0]']
#
#  dropout_36 (Dropout)           (None, 8, 8, 512)    0           ['conv2d_78[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 8, 8, 512)    2359808     ['dropout_36[0][0]']
#
#  dropout_37 (Dropout)           (None, 8, 8, 512)    0           ['conv2d_79[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 8, 8, 512)    2359808     ['dropout_37[0][0]']
#
#  up_sampling2d_11 (UpSampling2D  (None, 16, 16, 512)  0          ['conv2d_80[0][0]']
#  )
#
#  conv2d_81 (Conv2D)             (None, 16, 16, 256)  1179904     ['up_sampling2d_11[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 16, 16, 512)  0           ['conv2d_81[0][0]',
#                                                                   'conv2d_70[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 16, 16, 256)  1179904     ['concatenate_11[0][0]']
#
#  dropout_38 (Dropout)           (None, 16, 16, 256)  0           ['conv2d_82[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 16, 16, 256)  590080      ['dropout_38[0][0]']
#
#  dropout_39 (Dropout)           (None, 16, 16, 256)  0           ['conv2d_83[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 16, 16, 256)  590080      ['dropout_39[0][0]']
#
#  up_sampling2d_12 (UpSampling2D  (None, 32, 32, 256)  0          ['conv2d_84[0][0]']
#  )
#
#  conv2d_85 (Conv2D)             (None, 32, 32, 128)  295040      ['up_sampling2d_12[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 32, 32, 256)  0           ['conv2d_85[0][0]',
#                                                                   'conv2d_67[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_12[0][0]']
#
#  dropout_40 (Dropout)           (None, 32, 32, 128)  0           ['conv2d_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_40[0][0]']
#
#  dropout_41 (Dropout)           (None, 32, 32, 128)  0           ['conv2d_87[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_41[0][0]']
#
#  up_sampling2d_13 (UpSampling2D  (None, 64, 64, 128)  0          ['conv2d_88[0][0]']
#  )
#
#  conv2d_89 (Conv2D)             (None, 64, 64, 64)   73792       ['up_sampling2d_13[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 64, 64, 128)  0           ['conv2d_89[0][0]',
#                                                                   'conv2d_64[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_13[0][0]']
#
#  dropout_42 (Dropout)           (None, 64, 64, 64)   0           ['conv2d_90[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_42[0][0]']
#
#  dropout_43 (Dropout)           (None, 64, 64, 64)   0           ['conv2d_91[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_43[0][0]']
#
#  up_sampling2d_14 (UpSampling2D  (None, 128, 128, 64  0          ['conv2d_92[0][0]']
#  )                              )
#
#  conv2d_93 (Conv2D)             (None, 128, 128, 32  18464       ['up_sampling2d_14[0][0]']
#                                 )
#
#  concatenate_14 (Concatenate)   (None, 128, 128, 64  0           ['conv2d_93[0][0]',
#                                 )                                 'conv2d_61[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_14[0][0]']
#                                 )
#
#  dropout_44 (Dropout)           (None, 128, 128, 32  0           ['conv2d_94[0][0]']
#                                 )
#
#  conv2d_95 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_44[0][0]']
#                                 )
#
#  dropout_45 (Dropout)           (None, 128, 128, 32  0           ['conv2d_95[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_45[0][0]']
#                                 )
#
#  up_sampling2d_15 (UpSampling2D  (None, 256, 256, 32  0          ['conv2d_96[0][0]']
#  )                              )
#
#  conv2d_97 (Conv2D)             (None, 256, 256, 16  4624        ['up_sampling2d_15[0][0]']
#                                 )
#
#  concatenate_15 (Concatenate)   (None, 256, 256, 32  0           ['conv2d_97[0][0]',
#                                 )                                 'conv2d_58[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 256, 256, 16  4624        ['concatenate_15[0][0]']
#                                 )
#
#  dropout_46 (Dropout)           (None, 256, 256, 16  0           ['conv2d_98[0][0]']
#                                 )
#
#  conv2d_99 (Conv2D)             (None, 256, 256, 16  2320        ['dropout_46[0][0]']
#                                 )
#
#  dropout_47 (Dropout)           (None, 256, 256, 16  0           ['conv2d_99[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 256, 256, 16  2320        ['dropout_47[0][0]']
#                                 )
#
#  conv2d_101 (Conv2D)            (None, 256, 256, 1)  17          ['conv2d_100[0][0]']
#
# ==================================================================================================
# Total params: 50,334,545
# Trainable params: 50,334,545
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
unet_train_v3 = unet_model_v3.fit(train_gen,
                                  validation_data=val_gen,
                                  epochs = EPOCHS,
                                  steps_per_epoch = STEPS_PER_EPOCH,
                                  validation_steps = VALIDATION_STEPS,
                                  verbose = True)
# Out:
# Epoch 1/25
# 281/281 [==============================] - 73s 248ms/step - loss: 0.4975 - accuracy: 0.8160 - val_loss: 0.4467 - val_accuracy: 0.8090
# Epoch 2/25
# 281/281 [==============================] - 69s 245ms/step - loss: 0.4148 - accuracy: 0.8190 - val_loss: 0.4216 - val_accuracy: 0.8122
# Epoch 3/25
# 281/281 [==============================] - 69s 244ms/step - loss: 0.3868 - accuracy: 0.8273 - val_loss: 0.4256 - val_accuracy: 0.8106
# Epoch 4/25
# 281/281 [==============================] - 69s 245ms/step - loss: 0.3710 - accuracy: 0.8346 - val_loss: 0.3691 - val_accuracy: 0.8365
# Epoch 5/25
# 281/281 [==============================] - 69s 244ms/step - loss: 0.4094 - accuracy: 0.8241 - val_loss: 0.3943 - val_accuracy: 0.8247
# Epoch 6/25
# 281/281 [==============================] - 69s 245ms/step - loss: 0.3870 - accuracy: 0.8286 - val_loss: 0.3706 - val_accuracy: 0.8297
# Epoch 7/25
# 281/281 [==============================] - 69s 244ms/step - loss: 0.3605 - accuracy: 0.8416 - val_loss: 0.3497 - val_accuracy: 0.8433
# Epoch 8/25
# 281/281 [==============================] - 69s 245ms/step - loss: 0.3461 - accuracy: 0.8481 - val_loss: 0.3531 - val_accuracy: 0.8411
# Epoch 9/25
# 281/281 [==============================] - 69s 244ms/step - loss: 0.3378 - accuracy: 0.8516 - val_loss: 0.3340 - val_accuracy: 0.8520
# Epoch 10/25
# 281/281 [==============================] - 69s 244ms/step - loss: 0.3272 - accuracy: 0.8576 - val_loss: 0.3504 - val_accuracy: 0.8420
# Epoch 11/25
# 281/281 [==============================] - 69s 245ms/step - loss: 0.3313 - accuracy: 0.8540 - val_loss: 0.3197 - val_accuracy: 0.8607
# Epoch 12/25
# 281/281 [==============================] - 68s 244ms/step - loss: 0.3141 - accuracy: 0.8623 - val_loss: 0.3093 - val_accuracy: 0.8633
# Epoch 13/25
# 281/281 [==============================] - 69s 244ms/step - loss: 0.3140 - accuracy: 0.8632 - val_loss: 0.3099 - val_accuracy: 0.8624
# Epoch 14/25
# 281/281 [==============================] - 69s 245ms/step - loss: 0.3064 - accuracy: 0.8659 - val_loss: 0.2955 - val_accuracy: 0.8694
# Epoch 15/25
# 281/281 [==============================] - 69s 244ms/step - loss: 0.2956 - accuracy: 0.8714 - val_loss: 0.3006 - val_accuracy: 0.8647
# Epoch 16/25
# 281/281 [==============================] - 69s 245ms/step - loss: 0.2996 - accuracy: 0.8688 - val_loss: 0.3025 - val_accuracy: 0.8716
# Epoch 17/25
# 281/281 [==============================] - 69s 244ms/step - loss: 0.2880 - accuracy: 0.8745 - val_loss: 0.2855 - val_accuracy: 0.8742
# Epoch 18/25
# 281/281 [==============================] - 69s 244ms/step - loss: 0.2882 - accuracy: 0.8751 - val_loss: 0.2872 - val_accuracy: 0.8751
# Epoch 19/25
# 281/281 [==============================] - 69s 245ms/step - loss: 0.2842 - accuracy: 0.8769 - val_loss: 0.2825 - val_accuracy: 0.8783
# Epoch 20/25
# 281/281 [==============================] - 69s 245ms/step - loss: 0.2820 - accuracy: 0.8786 - val_loss: 0.2844 - val_accuracy: 0.8773
# Epoch 21/25
# 281/281 [==============================] - 69s 244ms/step - loss: 0.2727 - accuracy: 0.8818 - val_loss: 0.2738 - val_accuracy: 0.8795
# Epoch 22/25
# 281/281 [==============================] - 69s 245ms/step - loss: 0.2677 - accuracy: 0.8851 - val_loss: 0.2819 - val_accuracy: 0.8771
# Epoch 23/25
# 281/281 [==============================] - 69s 244ms/step - loss: 0.2663 - accuracy: 0.8869 - val_loss: 0.2606 - val_accuracy: 0.8876
# Epoch 24/25
# 281/281 [==============================] - 69s 244ms/step - loss: 0.2594 - accuracy: 0.8902 - val_loss: 0.2528 - val_accuracy: 0.8915
# Epoch 25/25
# 281/281 [==============================] - 69s 245ms/step - loss: 0.2534 - accuracy: 0.8929 - val_loss: 0.2577 - val_accuracy: 0.8911

# %%
unet_model_v3.save('unet_v3')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 46). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: unet_v3\assets
# INFO:tensorflow:Assets written to: unet_v3\assets

# %% [markdown]
# # U-Net version 4

# %%
def UNetModel_v4(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES):
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    x = inputs
    
    # Encoder part - contraction
    c1 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(x)
    c1 = BatchNormalization()(c1)
    d1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(d1)
    c1 = BatchNormalization()(c1)
    p1 = MaxPooling2D(pool_size = (2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(p1)
    c2 = BatchNormalization()(c2)
    d2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(d2)
    c2 = BatchNormalization()(c2)
    p2 = MaxPooling2D(pool_size = (2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(p2)
    c3 = BatchNormalization()(c3)
    d3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d3)
    c3 = BatchNormalization()(c3)
    p3 = MaxPooling2D(pool_size = (2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(p3)
    c4 = BatchNormalization()(c4)
    d4 = Dropout(0.2)(c4)    
    c4 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d4)
    c4 = BatchNormalization()(c4)
    p4 = MaxPooling2D(pool_size = (2, 2))(c4)
    
    ## Bottleneck part - bottom
    c5 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(p4)
    c5 = BatchNormalization()(c5)
    d5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d5)
    c5 = BatchNormalization()(c5)
    
    # Decoder part - expansion
    u6 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c5))
    u6 = concatenate([u6, c4], axis = 3)
    c6 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(u6)
    c6 = BatchNormalization()(c6)
    d6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d6)
    c6 = BatchNormalization()(c6)

    u7 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c6))
    u7 = concatenate([u7, c3], axis = 3)
    c7 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(u7)
    c7 = BatchNormalization()(c7)
    d7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d7)
    c7 = BatchNormalization()(c7)

    u8 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c7))
    u8 = concatenate([u8, c2], axis = 3)
    c8 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(u8)
    c8 = BatchNormalization()(c8)
    d8 = Dropout(0.1)(c8)
    c8 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(d8)
    c8 = BatchNormalization()(c8)

    u9 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c8))
    u9 = concatenate([u9, c1], axis = 3)
    c9 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(u9)
    c9 = BatchNormalization()(c9)
    d9 = Dropout(0.1)(c9)
    c9 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same')(d9)
    c9 = BatchNormalization()(c9)

    outputs = Conv2D(N_CLASSES, (1, 1), activation = 'sigmoid')(c9)
    
    model = Model(inputs, outputs, name = 'U-Net_v4')
    
    return model

# %%
unet_model_v4 = UNetModel_v4(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES)
unet_model_v4.compile(optimizer = OPTIMIZER (learning_rate = LEARNING_RATE), 
                      loss = LOSS, 
                      metrics = METRICS)
unet_model_v4.summary()
# Out:
# Model: "U-Net_v4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_23 (Conv2D)             (None, 256, 256, 16  448         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 256, 256, 16  64         ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  dropout_9 (Dropout)            (None, 256, 256, 16  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 256, 256, 16  2320        ['dropout_9[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 256, 256, 16  64         ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 16  0          ['batch_normalization_19[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 32  4640        ['max_pooling2d_4[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 128, 128, 32  128        ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  dropout_10 (Dropout)           (None, 128, 128, 32  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_10[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 32  128        ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 32)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 64)   18496       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 64)  256         ['conv2d_27[0][0]']
#  ormalization)
#
#  dropout_11 (Dropout)           (None, 64, 64, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_11[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 64)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 128)  73856       ['max_pooling2d_6[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 128)  512        ['conv2d_29[0][0]']
#  ormalization)
#
#  dropout_12 (Dropout)           (None, 32, 32, 128)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_12[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 128)  512        ['conv2d_30[0][0]']
#  ormalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 128)  0          ['batch_normalization_25[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 256)  295168      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_31[0][0]']
#  ormalization)
#
#  dropout_13 (Dropout)           (None, 16, 16, 256)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 256)  590080      ['dropout_13[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_32[0][0]']
#  ormalization)
#
#  up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 256)  0          ['batch_normalization_27[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 32, 32, 128)  295040      ['up_sampling2d_4[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 256)  0           ['conv2d_33[0][0]',
#                                                                   'batch_normalization_25[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_4[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 128)  512        ['conv2d_34[0][0]']
#  ormalization)
#
#  dropout_14 (Dropout)           (None, 32, 32, 128)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_14[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 128)  512        ['conv2d_35[0][0]']
#  ormalization)
#
#  up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 128)  0          ['batch_normalization_29[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 64, 64, 64)   73792       ['up_sampling2d_5[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_36[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_5[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 64, 64, 64)  256         ['conv2d_37[0][0]']
#  ormalization)
#
#  dropout_15 (Dropout)           (None, 64, 64, 64)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_15[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 64, 64, 64)  256         ['conv2d_38[0][0]']
#  ormalization)
#
#  up_sampling2d_6 (UpSampling2D)  (None, 128, 128, 64  0          ['batch_normalization_31[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 128, 128, 32  18464       ['up_sampling2d_6[0][0]']
#                                 )
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_39[0][0]',
#                                 )                                 'batch_normalization_21[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_6[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 128, 128, 32  128        ['conv2d_40[0][0]']
#  ormalization)                  )
#
#  dropout_16 (Dropout)           (None, 128, 128, 32  0           ['batch_normalization_32[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_16[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 128, 128, 32  128        ['conv2d_41[0][0]']
#  ormalization)                  )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 32  0          ['batch_normalization_33[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 256, 256, 16  4624        ['up_sampling2d_7[0][0]']
#                                 )
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 32  0           ['conv2d_42[0][0]',
#                                 )                                 'batch_normalization_19[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 256, 256, 16  4624        ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 256, 256, 16  64         ['conv2d_43[0][0]']
#  ormalization)                  )
#
#  dropout_17 (Dropout)           (None, 256, 256, 16  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 256, 256, 16  2320        ['dropout_17[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 256, 256, 16  64         ['conv2d_44[0][0]']
#  ormalization)                  )
#
#  conv2d_45 (Conv2D)             (None, 256, 256, 1)  17          ['batch_normalization_35[0][0]']
#
# ==================================================================================================
# Total params: 2,164,593
# Trainable params: 2,161,649
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
unet_train_v4 = unet_model_v4.fit(train_gen,
                                  validation_data=val_gen,
                                  epochs = EPOCHS,
                                  steps_per_epoch = STEPS_PER_EPOCH,
                                  validation_steps = VALIDATION_STEPS,
                                  verbose = True)
# Out:
# Epoch 1/25
# 281/281 [==============================] - 46s 163ms/step - loss: 0.1112 - accuracy: 0.9562 - val_loss: 0.2096 - val_accuracy: 0.9210
# Epoch 2/25
# 281/281 [==============================] - 46s 162ms/step - loss: 0.1169 - accuracy: 0.9542 - val_loss: 0.2267 - val_accuracy: 0.9260
# Epoch 3/25
# 281/281 [==============================] - 46s 162ms/step - loss: 0.1024 - accuracy: 0.9602 - val_loss: 0.2047 - val_accuracy: 0.9280
# Epoch 4/25
# 281/281 [==============================] - 45s 162ms/step - loss: 0.0999 - accuracy: 0.9613 - val_loss: 0.2093 - val_accuracy: 0.9293
# Epoch 5/25
# 281/281 [==============================] - 44s 158ms/step - loss: 0.0916 - accuracy: 0.9645 - val_loss: 0.2015 - val_accuracy: 0.9306
# Epoch 6/25
# 281/281 [==============================] - 46s 163ms/step - loss: 0.0914 - accuracy: 0.9645 - val_loss: 0.2062 - val_accuracy: 0.9321
# Epoch 7/25
# 281/281 [==============================] - 46s 162ms/step - loss: 0.0919 - accuracy: 0.9642 - val_loss: 0.2197 - val_accuracy: 0.9280
# Epoch 8/25
# 281/281 [==============================] - 46s 163ms/step - loss: 0.0899 - accuracy: 0.9648 - val_loss: 0.3141 - val_accuracy: 0.8964
# Epoch 9/25
# 281/281 [==============================] - 46s 163ms/step - loss: 0.0863 - accuracy: 0.9665 - val_loss: 0.2524 - val_accuracy: 0.9161
# Epoch 10/25
# 281/281 [==============================] - 46s 162ms/step - loss: 0.0860 - accuracy: 0.9665 - val_loss: 0.2145 - val_accuracy: 0.9294
# Epoch 11/25
# 281/281 [==============================] - 46s 163ms/step - loss: 0.0810 - accuracy: 0.9686 - val_loss: 0.2355 - val_accuracy: 0.9325
# Epoch 12/25
# 281/281 [==============================] - 46s 162ms/step - loss: 0.0854 - accuracy: 0.9668 - val_loss: 0.2166 - val_accuracy: 0.9298
# Epoch 13/25
# 281/281 [==============================] - 46s 162ms/step - loss: 0.0758 - accuracy: 0.9706 - val_loss: 0.2319 - val_accuracy: 0.9286
# Epoch 14/25
# 281/281 [==============================] - 46s 163ms/step - loss: 0.0815 - accuracy: 0.9687 - val_loss: 0.2260 - val_accuracy: 0.9309
# Epoch 15/25
# 281/281 [==============================] - 46s 162ms/step - loss: 0.0736 - accuracy: 0.9715 - val_loss: 0.2545 - val_accuracy: 0.9218
# Epoch 16/25
# 281/281 [==============================] - 45s 162ms/step - loss: 0.0844 - accuracy: 0.9672 - val_loss: 0.2530 - val_accuracy: 0.9267
# Epoch 17/25
# 281/281 [==============================] - 46s 162ms/step - loss: 0.0717 - accuracy: 0.9721 - val_loss: 0.2115 - val_accuracy: 0.9344
# Epoch 18/25
# 281/281 [==============================] - 44s 157ms/step - loss: 0.0693 - accuracy: 0.9731 - val_loss: 0.2318 - val_accuracy: 0.9232
# Epoch 19/25
# 281/281 [==============================] - 44s 157ms/step - loss: 0.0746 - accuracy: 0.9709 - val_loss: 0.2416 - val_accuracy: 0.9297
# Epoch 20/25
# 281/281 [==============================] - 46s 163ms/step - loss: 0.0761 - accuracy: 0.9703 - val_loss: 0.2599 - val_accuracy: 0.9307
# Epoch 21/25
# 281/281 [==============================] - 47s 166ms/step - loss: 0.0675 - accuracy: 0.9736 - val_loss: 0.2281 - val_accuracy: 0.9344
# Epoch 22/25
# 281/281 [==============================] - 47s 166ms/step - loss: 0.0671 - accuracy: 0.9738 - val_loss: 0.2482 - val_accuracy: 0.9316
# Epoch 23/25
# 281/281 [==============================] - 44s 158ms/step - loss: 0.0716 - accuracy: 0.9720 - val_loss: 0.2143 - val_accuracy: 0.9336
# Epoch 24/25
# 281/281 [==============================] - 45s 159ms/step - loss: 0.0722 - accuracy: 0.9720 - val_loss: 0.2251 - val_accuracy: 0.9278
# Epoch 25/25
# 281/281 [==============================] - 44s 158ms/step - loss: 0.0622 - accuracy: 0.9757 - val_loss: 0.2385 - val_accuracy: 0.9331

# %%
unet_model_v4.save('unet_v4_2')
# Out:
# [WARNING] save:__init__:233 - Found untraced functions such as %s while saving (showing %d of %d). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 23). These functions will not be directly callable after loading.
# [INFO   ] builder_impl:copy_assets_to_destination_dir:779 - Assets written to: %s
# INFO:tensorflow:Assets written to: unet_v4_2\assets
# INFO:tensorflow:Assets written to: unet_v4_2\assets

# %% [markdown]
# # U-Net version 5

# %%
def UNetModel_v5(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES):
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    x = inputs
    
    # Encoder part - contraction
    c1 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(x)
    c1 = BatchNormalization()(c1)
    d1 = Dropout(0.1)(c1)
    c1 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d1)
    c1 = BatchNormalization()(c1)
    p1 = MaxPooling2D(pool_size = (2, 2))(c1)

    c2 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(p1)
    c2 = BatchNormalization()(c2)
    d2 = Dropout(0.1)(c2)
    c2 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d2)
    c2 = BatchNormalization()(c2)
    p2 = MaxPooling2D(pool_size = (2, 2))(c2)

    c3 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(p2)
    c3 = BatchNormalization()(c3)
    d3 = Dropout(0.2)(c3)
    c3 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d3)
    c3 = BatchNormalization()(c3)
    p3 = MaxPooling2D(pool_size = (2, 2))(c3)

    c4 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(p3)
    c4 = BatchNormalization()(c4)
    d4 = Dropout(0.2)(c4)    
    c4 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d4)
    c4 = BatchNormalization()(c4)
    p4 = MaxPooling2D(pool_size = (2, 2))(c4)
    
    ## Bottleneck part - bottom
    c5 = Conv2D(1024, (3, 3), activation = 'relu', padding = 'same')(p4)
    c5 = BatchNormalization()(c5)
    d5 = Dropout(0.3)(c5)
    c5 = Conv2D(1024, (3, 3), activation = 'relu', padding = 'same')(d5)
    c5 = BatchNormalization()(c5)
    
    # Decoder part - expansion
    u6 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c5))
    u6 = concatenate([u6, c4], axis = 3)
    c6 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(u6)
    c6 = BatchNormalization()(c6)
    d6 = Dropout(0.2)(c6)
    c6 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d6)
    c6 = BatchNormalization()(c6)

    u7 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c6))
    u7 = concatenate([u7, c3], axis = 3)
    c7 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(u7)
    c7 = BatchNormalization()(c7)
    d7 = Dropout(0.2)(c7)
    c7 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d7)
    c7 = BatchNormalization()(c7)

    u8 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c7))
    u8 = concatenate([u8, c2], axis = 3)
    c8 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(u8)
    c8 = BatchNormalization()(c8)
    d8 = Dropout(0.1)(c8)
    c8 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d8)
    c8 = BatchNormalization()(c8)

    u9 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c8))
    u9 = concatenate([u9, c1], axis = 3)
    c9 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(u9)
    c9 = BatchNormalization()(c9)
    d9 = Dropout(0.1)(c9)
    c9 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d9)
    c9 = BatchNormalization()(c9)

    outputs = Conv2D(N_CLASSES, (1, 1), activation = 'sigmoid')(c9)
    
    model = Model(inputs, outputs, name = 'U-Net_v5')
    
    return model

# %%
unet_model_v5 = UNetModel_v5(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES)
unet_model_v5.compile(optimizer = OPTIMIZER (learning_rate = LEARNING_RATE_small), 
                      loss = LOSS, 
                      metrics = METRICS)
unet_model_v5.summary()
# Out:
# Model: "U-Net_v5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_69 (Conv2D)             (None, 256, 256, 64  1792        ['input_4[0][0]']
#                                 )
#
#  batch_normalization_54 (BatchN  (None, 256, 256, 64  256        ['conv2d_69[0][0]']
#  ormalization)                  )
#
#  dropout_27 (Dropout)           (None, 256, 256, 64  0           ['batch_normalization_54[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 256, 256, 64  36928       ['dropout_27[0][0]']
#                                 )
#
#  batch_normalization_55 (BatchN  (None, 256, 256, 64  256        ['conv2d_70[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 128, 128, 64  0          ['batch_normalization_55[0][0]']
#  )                              )
#
#  conv2d_71 (Conv2D)             (None, 128, 128, 12  73856       ['max_pooling2d_12[0][0]']
#                                 8)
#
#  batch_normalization_56 (BatchN  (None, 128, 128, 12  512        ['conv2d_71[0][0]']
#  ormalization)                  8)
#
#  dropout_28 (Dropout)           (None, 128, 128, 12  0           ['batch_normalization_56[0][0]']
#                                 8)
#
#  conv2d_72 (Conv2D)             (None, 128, 128, 12  147584      ['dropout_28[0][0]']
#                                 8)
#
#  batch_normalization_57 (BatchN  (None, 128, 128, 12  512        ['conv2d_72[0][0]']
#  ormalization)                  8)
#
#  max_pooling2d_13 (MaxPooling2D  (None, 64, 64, 128)  0          ['batch_normalization_57[0][0]']
#  )
#
#  conv2d_73 (Conv2D)             (None, 64, 64, 256)  295168      ['max_pooling2d_13[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_73[0][0]']
#  ormalization)
#
#  dropout_29 (Dropout)           (None, 64, 64, 256)  0           ['batch_normalization_58[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 64, 64, 256)  590080      ['dropout_29[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_74[0][0]']
#  ormalization)
#
#  max_pooling2d_14 (MaxPooling2D  (None, 32, 32, 256)  0          ['batch_normalization_59[0][0]']
#  )
#
#  conv2d_75 (Conv2D)             (None, 32, 32, 512)  1180160     ['max_pooling2d_14[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_75[0][0]']
#  ormalization)
#
#  dropout_30 (Dropout)           (None, 32, 32, 512)  0           ['batch_normalization_60[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 32, 32, 512)  2359808     ['dropout_30[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_76[0][0]']
#  ormalization)
#
#  max_pooling2d_15 (MaxPooling2D  (None, 16, 16, 512)  0          ['batch_normalization_61[0][0]']
#  )
#
#  conv2d_77 (Conv2D)             (None, 16, 16, 1024  4719616     ['max_pooling2d_15[0][0]']
#                                 )
#
#  batch_normalization_62 (BatchN  (None, 16, 16, 1024  4096       ['conv2d_77[0][0]']
#  ormalization)                  )
#
#  dropout_31 (Dropout)           (None, 16, 16, 1024  0           ['batch_normalization_62[0][0]']
#                                 )
#
#  conv2d_78 (Conv2D)             (None, 16, 16, 1024  9438208     ['dropout_31[0][0]']
#                                 )
#
#  batch_normalization_63 (BatchN  (None, 16, 16, 1024  4096       ['conv2d_78[0][0]']
#  ormalization)                  )
#
#  up_sampling2d_12 (UpSampling2D  (None, 32, 32, 1024  0          ['batch_normalization_63[0][0]']
#  )                              )
#
#  conv2d_79 (Conv2D)             (None, 32, 32, 512)  4719104     ['up_sampling2d_12[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 32, 32, 1024  0           ['conv2d_79[0][0]',
#                                 )                                 'batch_normalization_61[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate_12[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_80[0][0]']
#  ormalization)
#
#  dropout_32 (Dropout)           (None, 32, 32, 512)  0           ['batch_normalization_64[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 32, 32, 512)  2359808     ['dropout_32[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_81[0][0]']
#  ormalization)
#
#  up_sampling2d_13 (UpSampling2D  (None, 64, 64, 512)  0          ['batch_normalization_65[0][0]']
#  )
#
#  conv2d_82 (Conv2D)             (None, 64, 64, 256)  1179904     ['up_sampling2d_13[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_82[0][0]',
#                                                                   'batch_normalization_59[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_13[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_83[0][0]']
#  ormalization)
#
#  dropout_33 (Dropout)           (None, 64, 64, 256)  0           ['batch_normalization_66[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 64, 64, 256)  590080      ['dropout_33[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_84[0][0]']
#  ormalization)
#
#  up_sampling2d_14 (UpSampling2D  (None, 128, 128, 25  0          ['batch_normalization_67[0][0]']
#  )                              6)
#
#  conv2d_85 (Conv2D)             (None, 128, 128, 12  295040      ['up_sampling2d_14[0][0]']
#                                 8)
#
#  concatenate_14 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_85[0][0]',
#                                 6)                                'batch_normalization_57[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_14[0][0]']
#                                 8)
#
#  batch_normalization_68 (BatchN  (None, 128, 128, 12  512        ['conv2d_86[0][0]']
#  ormalization)                  8)
#
#  dropout_34 (Dropout)           (None, 128, 128, 12  0           ['batch_normalization_68[0][0]']
#                                 8)
#
#  conv2d_87 (Conv2D)             (None, 128, 128, 12  147584      ['dropout_34[0][0]']
#                                 8)
#
#  batch_normalization_69 (BatchN  (None, 128, 128, 12  512        ['conv2d_87[0][0]']
#  ormalization)                  8)
#
#  up_sampling2d_15 (UpSampling2D  (None, 256, 256, 12  0          ['batch_normalization_69[0][0]']
#  )                              8)
#
#  conv2d_88 (Conv2D)             (None, 256, 256, 64  73792       ['up_sampling2d_15[0][0]']
#                                 )
#
#  concatenate_15 (Concatenate)   (None, 256, 256, 12  0           ['conv2d_88[0][0]',
#                                 8)                                'batch_normalization_55[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_15[0][0]']
#                                 )
#
#  batch_normalization_70 (BatchN  (None, 256, 256, 64  256        ['conv2d_89[0][0]']
#  ormalization)                  )
#
#  dropout_35 (Dropout)           (None, 256, 256, 64  0           ['batch_normalization_70[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 256, 256, 64  36928       ['dropout_35[0][0]']
#                                 )
#
#  batch_normalization_71 (BatchN  (None, 256, 256, 64  256        ['conv2d_90[0][0]']
#  ormalization)                  )
#
#  conv2d_91 (Conv2D)             (None, 256, 256, 1)  65          ['batch_normalization_71[0][0]']
#
# ==================================================================================================
# Total params: 34,536,897
# Trainable params: 34,525,121
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
unet_train_v5 = unet_model_v5.fit(train_gen_small,
                                  validation_data=val_gen_small,
                                  epochs = EPOCHS,
                                  steps_per_epoch = STEPS_PER_EPOCH_small,
                                  validation_steps = VALIDATION_STEPS_small,
                                  verbose = True)
# Out:
# Epoch 1/25
# 563/563 [==============================] - 217s 377ms/step - loss: 0.6939 - accuracy: 0.6362 - val_loss: 0.4912 - val_accuracy: 0.8134
# Epoch 2/25
# 563/563 [==============================] - 211s 375ms/step - loss: 0.5926 - accuracy: 0.7635 - val_loss: 0.4616 - val_accuracy: 0.8378
# Epoch 3/25
# 563/563 [==============================] - 210s 373ms/step - loss: 0.5526 - accuracy: 0.8031 - val_loss: 0.4315 - val_accuracy: 0.8487
# Epoch 4/25
# 563/563 [==============================] - 211s 374ms/step - loss: 0.5183 - accuracy: 0.8242 - val_loss: 0.4788 - val_accuracy: 0.8440
# Epoch 5/25
# 563/563 [==============================] - 210s 373ms/step - loss: 0.4879 - accuracy: 0.8402 - val_loss: 0.3991 - val_accuracy: 0.8565
# Epoch 6/25
# 563/563 [==============================] - 210s 373ms/step - loss: 0.4650 - accuracy: 0.8480 - val_loss: 0.4295 - val_accuracy: 0.8509
# Epoch 7/25
# 563/563 [==============================] - 211s 375ms/step - loss: 0.4422 - accuracy: 0.8569 - val_loss: 0.4015 - val_accuracy: 0.8577
# Epoch 8/25
# 563/563 [==============================] - 225s 399ms/step - loss: 0.4204 - accuracy: 0.8617 - val_loss: 0.5483 - val_accuracy: 0.8598
# Epoch 9/25
# 563/563 [==============================] - 236s 419ms/step - loss: 0.4049 - accuracy: 0.8653 - val_loss: 0.4703 - val_accuracy: 0.8423
# Epoch 10/25
# 563/563 [==============================] - 236s 419ms/step - loss: 0.3917 - accuracy: 0.8699 - val_loss: 0.4232 - val_accuracy: 0.8520
# Epoch 11/25
# 563/563 [==============================] - 236s 419ms/step - loss: 0.3822 - accuracy: 0.8736 - val_loss: 0.5148 - val_accuracy: 0.8611
# Epoch 12/25
# 563/563 [==============================] - 237s 421ms/step - loss: 0.3594 - accuracy: 0.8764 - val_loss: 0.4168 - val_accuracy: 0.8534
# Epoch 13/25
# 563/563 [==============================] - 236s 419ms/step - loss: 0.3384 - accuracy: 0.8832 - val_loss: 0.4096 - val_accuracy: 0.8451
# Epoch 14/25
# 563/563 [==============================] - 236s 419ms/step - loss: 0.3443 - accuracy: 0.8805 - val_loss: 0.3946 - val_accuracy: 0.8670
# Epoch 15/25
# 563/563 [==============================] - 236s 419ms/step - loss: 0.3261 - accuracy: 0.8844 - val_loss: 0.5685 - val_accuracy: 0.8625
# Epoch 16/25
# 563/563 [==============================] - 236s 419ms/step - loss: 0.3193 - accuracy: 0.8877 - val_loss: 0.5311 - val_accuracy: 0.8283
# Epoch 17/25
# 563/563 [==============================] - 236s 419ms/step - loss: 0.3111 - accuracy: 0.8892 - val_loss: 0.4554 - val_accuracy: 0.8506
# Epoch 18/25
# 563/563 [==============================] - 235s 418ms/step - loss: 0.2968 - accuracy: 0.8924 - val_loss: 0.5874 - val_accuracy: 0.8404
# Epoch 19/25
# 563/563 [==============================] - 235s 418ms/step - loss: 0.3026 - accuracy: 0.8911 - val_loss: 0.3928 - val_accuracy: 0.8593
# Epoch 20/25
# 563/563 [==============================] - 236s 419ms/step - loss: 0.3021 - accuracy: 0.8917 - val_loss: 0.3401 - val_accuracy: 0.8718
# Epoch 21/25
# 563/563 [==============================] - 236s 419ms/step - loss: 0.2834 - accuracy: 0.8956 - val_loss: 0.5686 - val_accuracy: 0.8594
# Epoch 22/25
# 563/563 [==============================] - 236s 419ms/step - loss: 0.2720 - accuracy: 0.8989 - val_loss: 0.3548 - val_accuracy: 0.8759
# Epoch 23/25
# 563/563 [==============================] - 236s 419ms/step - loss: 0.2657 - accuracy: 0.9004 - val_loss: 0.3830 - val_accuracy: 0.8700
# Epoch 24/25
# 563/563 [==============================] - 236s 419ms/step - loss: 0.2738 - accuracy: 0.8984 - val_loss: 0.3618 - val_accuracy: 0.8573
# Epoch 25/25
# 563/563 [==============================] - 236s 419ms/step - loss: 0.2585 - accuracy: 0.9032 - val_loss: 0.3457 - val_accuracy: 0.8681

# %%
unet_model_v5.save('unet_v5')
# Out:
# [WARNING] save:__init__:233 - Found untraced functions such as %s while saving (showing %d of %d). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 23). These functions will not be directly callable after loading.
# [INFO   ] builder_impl:copy_assets_to_destination_dir:779 - Assets written to: %s
# INFO:tensorflow:Assets written to: unet_v5\assets
# INFO:tensorflow:Assets written to: unet_v5\assets

# %% [markdown]
# # Pre-Trained VGG16

# %%
def VGG16Model_tl(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES):
    
    conv_base = VGG16(include_top=False,
                     weights='imagenet', 
                     input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    
    # Create a new 'top' of the model (i.e. fully-connected layers).
    # This is 'bootstrapping' a new top_model onto the pretrained layers.
    l1 = conv_base.output
    l2 = Flatten(name="flatten")(l1)
    l3 = Dense(4096, activation='relu')(l2)
    l4 = Dense(4096, activation='relu')(l3)
    l5 = Dense(1000, activation='relu')(l4)
    l6 = Dropout(0.2)(l5)
    l7 = Dense(65536, activation='softmax')(l6)
    outputs = tf.reshape(l7, (-1, IMG_HEIGHT, IMG_WIDTH, N_CLASSES))
    
    model = Model(conv_base.input, outputs, name = 'VGG16_tl')
    
    for layer in model.layers[:-6]:
        layer.trainable = False
    
    return model

# %%
vgg16_model_tl = VGG16Model_tl(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES)
vgg16_model_tl.compile(optimizer = OPTIMIZER (learning_rate = LEARNING_RATE_small), 
                      loss = LOSS, 
                      metrics = METRICS)
vgg16_model_tl.summary()
# Out:
# Model: "VGG16_tl"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense_12 (Dense)            (None, 4096)              134221824
#
#  dense_13 (Dense)            (None, 4096)              16781312
#
#  dense_14 (Dense)            (None, 1000)              4097000
#
#  dropout_3 (Dropout)         (None, 1000)              0
#
#  dense_15 (Dense)            (None, 65536)             65601536
#
#  tf.reshape_3 (TFOpLambda)   (None, 256, 256, 1)       0
#
# =================================================================
# Total params: 235,416,360
# Trainable params: 220,701,672
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
vgg16_train_yl = vgg16_model_tl.fit(train_gen_small,
                                  validation_data=val_gen_small,
                                  epochs = EPOCHS,
                                  steps_per_epoch = STEPS_PER_EPOCH_small,
                                  validation_steps = VALIDATION_STEPS_small,
                                  verbose = True)
# Out:
# Epoch 1/25
# 563/563 [==============================] - 209s 371ms/step - loss: 1.9780 - accuracy: 0.8168 - val_loss: 2.0444 - val_accuracy: 0.8101
# Epoch 2/25
# 563/563 [==============================] - 68s 120ms/step - loss: 1.9448 - accuracy: 0.8188 - val_loss: 2.0219 - val_accuracy: 0.8104
# Epoch 3/25
# 563/563 [==============================] - 66s 117ms/step - loss: 1.8979 - accuracy: 0.8210 - val_loss: 2.0135 - val_accuracy: 0.8103
# Epoch 4/25
# 563/563 [==============================] - 67s 119ms/step - loss: 1.8995 - accuracy: 0.8197 - val_loss: 2.0028 - val_accuracy: 0.8105
# Epoch 5/25
# 563/563 [==============================] - 65s 116ms/step - loss: 1.8920 - accuracy: 0.8193 - val_loss: 1.9993 - val_accuracy: 0.8105
# Epoch 6/25
# 563/563 [==============================] - 65s 116ms/step - loss: 1.8946 - accuracy: 0.8181 - val_loss: 2.0016 - val_accuracy: 0.8103
# Epoch 7/25
# 563/563 [==============================] - 67s 118ms/step - loss: 1.8683 - accuracy: 0.8199 - val_loss: 2.0102 - val_accuracy: 0.8094
# Epoch 8/25
# 563/563 [==============================] - 67s 119ms/step - loss: 1.8796 - accuracy: 0.8181 - val_loss: 1.9722 - val_accuracy: 0.8129
# Epoch 9/25
# 563/563 [==============================] - 68s 121ms/step - loss: 1.8453 - accuracy: 0.8208 - val_loss: 2.0272 - val_accuracy: 0.8079
# Epoch 10/25
# 563/563 [==============================] - 69s 123ms/step - loss: 1.8991 - accuracy: 0.8156 - val_loss: 1.9896 - val_accuracy: 0.8112
# Epoch 11/25
# 563/563 [==============================] - 71s 125ms/step - loss: 1.8403 - accuracy: 0.8206 - val_loss: 2.0078 - val_accuracy: 0.8095
# Epoch 12/25
# 563/563 [==============================] - 66s 118ms/step - loss: 1.8522 - accuracy: 0.8192 - val_loss: 1.9913 - val_accuracy: 0.8113
# Epoch 13/25
# 563/563 [==============================] - 68s 121ms/step - loss: 1.8547 - accuracy: 0.8186 - val_loss: 2.0221 - val_accuracy: 0.8085
# Epoch 14/25
# 563/563 [==============================] - 73s 129ms/step - loss: 1.8527 - accuracy: 0.8186 - val_loss: 2.0119 - val_accuracy: 0.8099
# Epoch 15/25
# 563/563 [==============================] - 66s 117ms/step - loss: 1.8357 - accuracy: 0.8200 - val_loss: 2.0263 - val_accuracy: 0.8088
# Epoch 16/25
# 563/563 [==============================] - 64s 114ms/step - loss: 1.8504 - accuracy: 0.8184 - val_loss: 1.9648 - val_accuracy: 0.8141
# Epoch 17/25
# 563/563 [==============================] - 76s 135ms/step - loss: 1.8413 - accuracy: 0.8190 - val_loss: 2.0175 - val_accuracy: 0.8090
# Epoch 18/25
# 563/563 [==============================] - 66s 118ms/step - loss: 1.8351 - accuracy: 0.8194 - val_loss: 2.0070 - val_accuracy: 0.8099
# Epoch 19/25
# 563/563 [==============================] - 66s 118ms/step - loss: 1.8506 - accuracy: 0.8178 - val_loss: 2.0316 - val_accuracy: 0.8077
# Epoch 20/25
# 563/563 [==============================] - 65s 116ms/step - loss: 1.8249 - accuracy: 0.8200 - val_loss: 1.9685 - val_accuracy: 0.8133
# Epoch 21/25
# 563/563 [==============================] - 69s 123ms/step - loss: 1.8412 - accuracy: 0.8183 - val_loss: 2.0070 - val_accuracy: 0.8102
# Epoch 22/25
# 563/563 [==============================] - 69s 123ms/step - loss: 1.8374 - accuracy: 0.8185 - val_loss: 1.9829 - val_accuracy: 0.8121
# Epoch 23/25
# 563/563 [==============================] - 68s 120ms/step - loss: 1.8086 - accuracy: 0.8212 - val_loss: 2.0026 - val_accuracy: 0.8109
# Epoch 24/25
# 563/563 [==============================] - 69s 123ms/step - loss: 1.8312 - accuracy: 0.8188 - val_loss: 2.0244 - val_accuracy: 0.8091
# Epoch 25/25
# 563/563 [==============================] - 69s 122ms/step - loss: 1.8171 - accuracy: 0.8200 - val_loss: 1.9888 - val_accuracy: 0.8126

# %%
vgg16_model_tl.save('vgg16_tl')
# Out:
# [WARNING] save:__init__:233 - Found untraced functions such as %s while saving (showing %d of %d). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# [INFO   ] builder_impl:copy_assets_to_destination_dir:779 - Assets written to: %s
# INFO:tensorflow:Assets written to: vgg16_tl\assets
# INFO:tensorflow:Assets written to: vgg16_tl\assets

# %% [markdown]
# # Pre-Trained ResNet50

# %%
def ResNet50Model_tl(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES):
    
    res_base = ResNet50(include_top=False,
                         weights='imagenet', 
                         input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    
    l1 = res_base.output
    l2 = Flatten()(l1)
    l3 = Dense(500, activation='relu')(l2)
    l4 = Dropout(0.2)(l3)
    l5 = Dense(750, activation='relu')(l4)
    l6 = Dropout(0.2)(l5)
    l7 = Dense(1000, activation='relu')(l6)
    l8 = Dense(65536, activation='softmax')(l7)
    outputs = tf.reshape(l8, (-1, IMG_HEIGHT, IMG_WIDTH, N_CLASSES))
    
    model = Model(res_base.input, outputs, name = 'ResNet50_tl')
    
    for layer in model.layers[:-7]:
        layer.trainable = False
    
    return model

# %%
resnet50_model_tl_1 = ResNet50Model_tl(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES)
resnet50_model_tl_1.compile(optimizer = RMSprop (learning_rate = LEARNING_RATE_small), 
                      loss = LOSS, 
                      metrics = METRICS)
resnet50_model_tl_1.summary()
# Out:
# Model: "ResNet50_tl"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 262, 262, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 128, 128, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 128, 128, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 128, 128, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 130, 130, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 64, 64, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 64, 64, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 64, 64, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 64, 64, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 64, 64, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 64, 64, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 64, 64, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 64, 64, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 64, 64, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 64, 64, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 64, 64, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 64, 64, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 64, 64, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 64, 64, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 32, 32, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 32, 32, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 32, 32, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 32, 32, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 32, 32, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 32, 32, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 16, 16, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 16, 16, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 16, 16, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 16, 16, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 16, 16, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 16, 16, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 16, 16, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 16, 16, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 8, 8, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 8, 8, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 8, 8, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 8, 8, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 8, 8, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 8, 8, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 8, 8, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 8, 8, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 8, 8, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 8, 8, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 8, 8, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 8, 8, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 8, 8, 2048)   0           ['conv5_block3_add[0][0]']
#
#  flatten_1 (Flatten)            (None, 131072)       0           ['conv5_block3_out[0][0]']
#
#  dense_4 (Dense)                (None, 500)          65536500    ['flatten_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 500)          0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 750)          375750      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 750)          0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 1000)         751000      ['dropout_3[0][0]']
#
#  dense_7 (Dense)                (None, 65536)        65601536    ['dense_6[0][0]']
#
#  tf.reshape_1 (TFOpLambda)      (None, 256, 256, 1)  0           ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 155,852,498
# Trainable params: 132,264,786
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
resnet50_train_yl_1 = resnet50_model_tl_1.fit(train_gen_small,
                                  validation_data=val_gen_small,
                                  epochs = 100,
                                  steps_per_epoch = STEPS_PER_EPOCH_small,
                                  validation_steps = VALIDATION_STEPS_small,
                                  verbose = True)
# Out:
# Epoch 1/100
# 563/563 [==============================] - 105s 183ms/step - loss: 1.9795 - accuracy: 0.8174 - val_loss: 2.0566 - val_accuracy: 0.8099
# Epoch 2/100
# 563/563 [==============================] - 55s 98ms/step - loss: 1.9692 - accuracy: 0.8180 - val_loss: 2.0599 - val_accuracy: 0.8093
# Epoch 3/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9679 - accuracy: 0.8179 - val_loss: 2.0414 - val_accuracy: 0.8111
# Epoch 4/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9138 - accuracy: 0.8227 - val_loss: 2.0504 - val_accuracy: 0.8106
# Epoch 5/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9624 - accuracy: 0.8184 - val_loss: 2.0373 - val_accuracy: 0.8114
# Epoch 6/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9664 - accuracy: 0.8179 - val_loss: 2.0580 - val_accuracy: 0.8094
# Epoch 7/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9348 - accuracy: 0.8210 - val_loss: 2.0421 - val_accuracy: 0.8109
# Epoch 8/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9759 - accuracy: 0.8169 - val_loss: 2.0438 - val_accuracy: 0.8107
# Epoch 9/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9443 - accuracy: 0.8199 - val_loss: 2.0473 - val_accuracy: 0.8105
# Epoch 10/100
# 563/563 [==============================] - 52s 93ms/step - loss: 1.9651 - accuracy: 0.8180 - val_loss: 2.0640 - val_accuracy: 0.8092
# Epoch 11/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9745 - accuracy: 0.8170 - val_loss: 2.0501 - val_accuracy: 0.8101
# Epoch 12/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.8943 - accuracy: 0.8245 - val_loss: 2.0422 - val_accuracy: 0.8109
# Epoch 13/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9618 - accuracy: 0.8183 - val_loss: 2.1033 - val_accuracy: 0.8053
# Epoch 14/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9645 - accuracy: 0.8180 - val_loss: 2.0013 - val_accuracy: 0.8144
# Epoch 15/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9799 - accuracy: 0.8166 - val_loss: 2.0834 - val_accuracy: 0.8072
# Epoch 16/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9330 - accuracy: 0.8209 - val_loss: 2.0098 - val_accuracy: 0.8138
# Epoch 17/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9653 - accuracy: 0.8178 - val_loss: 2.0751 - val_accuracy: 0.8079
# Epoch 18/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9348 - accuracy: 0.8206 - val_loss: 2.0212 - val_accuracy: 0.8127
# Epoch 19/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9552 - accuracy: 0.8189 - val_loss: 2.0661 - val_accuracy: 0.8086
# Epoch 20/100
# 563/563 [==============================] - 51s 90ms/step - loss: 1.9476 - accuracy: 0.8194 - val_loss: 2.0782 - val_accuracy: 0.8074
# Epoch 21/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9702 - accuracy: 0.8174 - val_loss: 2.0304 - val_accuracy: 0.8121
# Epoch 22/100
# 563/563 [==============================] - 51s 90ms/step - loss: 1.9542 - accuracy: 0.8188 - val_loss: 2.0552 - val_accuracy: 0.8098
# Epoch 23/100
# 563/563 [==============================] - 51s 90ms/step - loss: 1.9488 - accuracy: 0.8194 - val_loss: 2.0349 - val_accuracy: 0.8113
# Epoch 24/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9551 - accuracy: 0.8187 - val_loss: 2.0611 - val_accuracy: 0.8092
# Epoch 25/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9494 - accuracy: 0.8192 - val_loss: 2.0284 - val_accuracy: 0.8121
# Epoch 26/100
# 563/563 [==============================] - 51s 90ms/step - loss: 1.9590 - accuracy: 0.8184 - val_loss: 2.0662 - val_accuracy: 0.8085
# Epoch 27/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9225 - accuracy: 0.8216 - val_loss: 2.0309 - val_accuracy: 0.8117
# Epoch 28/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9809 - accuracy: 0.8162 - val_loss: 2.0626 - val_accuracy: 0.8088
# Epoch 29/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9420 - accuracy: 0.8198 - val_loss: 2.0196 - val_accuracy: 0.8128
# Epoch 30/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9526 - accuracy: 0.8189 - val_loss: 2.0690 - val_accuracy: 0.8082
# Epoch 31/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9433 - accuracy: 0.8196 - val_loss: 2.0157 - val_accuracy: 0.8129
# Epoch 32/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9517 - accuracy: 0.8187 - val_loss: 2.0791 - val_accuracy: 0.8075
# Epoch 33/100
# 563/563 [==============================] - 53s 94ms/step - loss: 1.9624 - accuracy: 0.8180 - val_loss: 2.0101 - val_accuracy: 0.8135
# Epoch 34/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9251 - accuracy: 0.8211 - val_loss: 2.0770 - val_accuracy: 0.8076
# Epoch 35/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9686 - accuracy: 0.8173 - val_loss: 2.0643 - val_accuracy: 0.8088
# Epoch 36/100
# 563/563 [==============================] - 52s 93ms/step - loss: 1.9586 - accuracy: 0.8182 - val_loss: 2.0262 - val_accuracy: 0.8122
# Epoch 37/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9273 - accuracy: 0.8210 - val_loss: 2.0608 - val_accuracy: 0.8089
# Epoch 38/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9482 - accuracy: 0.8191 - val_loss: 2.0305 - val_accuracy: 0.8118
# Epoch 39/100
# 563/563 [==============================] - 52s 93ms/step - loss: 1.9201 - accuracy: 0.8216 - val_loss: 2.0245 - val_accuracy: 0.8121
# Epoch 40/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9676 - accuracy: 0.8172 - val_loss: 2.0436 - val_accuracy: 0.8105
# Epoch 41/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9302 - accuracy: 0.8205 - val_loss: 2.0138 - val_accuracy: 0.8130
# Epoch 42/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9706 - accuracy: 0.8169 - val_loss: 2.0966 - val_accuracy: 0.8056
# Epoch 43/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9295 - accuracy: 0.8204 - val_loss: 2.0112 - val_accuracy: 0.8133
# Epoch 44/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9755 - accuracy: 0.8164 - val_loss: 2.0588 - val_accuracy: 0.8093
# Epoch 45/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9712 - accuracy: 0.8166 - val_loss: 2.0319 - val_accuracy: 0.8114
# Epoch 46/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9209 - accuracy: 0.8213 - val_loss: 2.1002 - val_accuracy: 0.8055
# Epoch 47/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9152 - accuracy: 0.8217 - val_loss: 2.0075 - val_accuracy: 0.8136
# Epoch 48/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9656 - accuracy: 0.8172 - val_loss: 2.0473 - val_accuracy: 0.8099
# Epoch 49/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9427 - accuracy: 0.8191 - val_loss: 2.0749 - val_accuracy: 0.8078
# Epoch 50/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9666 - accuracy: 0.8171 - val_loss: 2.0303 - val_accuracy: 0.8113
# Epoch 51/100
# 563/563 [==============================] - 52s 93ms/step - loss: 1.9104 - accuracy: 0.8221 - val_loss: 2.0803 - val_accuracy: 0.8073
# Epoch 52/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9562 - accuracy: 0.8180 - val_loss: 2.0026 - val_accuracy: 0.8142
# Epoch 53/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9612 - accuracy: 0.8172 - val_loss: 2.0670 - val_accuracy: 0.8082
# Epoch 54/100
# 563/563 [==============================] - 52s 93ms/step - loss: 1.9139 - accuracy: 0.8216 - val_loss: 2.0369 - val_accuracy: 0.8112
# Epoch 55/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9478 - accuracy: 0.8186 - val_loss: 2.0063 - val_accuracy: 0.8137
# Epoch 56/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9484 - accuracy: 0.8186 - val_loss: 2.1074 - val_accuracy: 0.8049
# Epoch 57/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9138 - accuracy: 0.8216 - val_loss: 2.0257 - val_accuracy: 0.8124
# Epoch 58/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9777 - accuracy: 0.8156 - val_loss: 2.0198 - val_accuracy: 0.8122
# Epoch 59/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9303 - accuracy: 0.8201 - val_loss: 2.0374 - val_accuracy: 0.8110
# Epoch 60/100
# 563/563 [==============================] - 52s 93ms/step - loss: 1.9431 - accuracy: 0.8189 - val_loss: 2.0632 - val_accuracy: 0.8086
# Epoch 61/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9089 - accuracy: 0.8221 - val_loss: 2.0678 - val_accuracy: 0.8083
# Epoch 62/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9703 - accuracy: 0.8163 - val_loss: 2.0170 - val_accuracy: 0.8125
# Epoch 63/100
# 563/563 [==============================] - 52s 93ms/step - loss: 1.9437 - accuracy: 0.8188 - val_loss: 2.0374 - val_accuracy: 0.8109
# Epoch 64/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9241 - accuracy: 0.8205 - val_loss: 2.0732 - val_accuracy: 0.8075
# Epoch 65/100
# 563/563 [==============================] - 52s 93ms/step - loss: 1.9557 - accuracy: 0.8177 - val_loss: 2.0324 - val_accuracy: 0.8113
# Epoch 66/100
# 563/563 [==============================] - 53s 94ms/step - loss: 1.9465 - accuracy: 0.8183 - val_loss: 2.0050 - val_accuracy: 0.8137
# Epoch 67/100
# 563/563 [==============================] - 52s 93ms/step - loss: 1.9189 - accuracy: 0.8209 - val_loss: 2.0550 - val_accuracy: 0.8093
# Epoch 68/100
# 563/563 [==============================] - 53s 94ms/step - loss: 1.9564 - accuracy: 0.8175 - val_loss: 2.0545 - val_accuracy: 0.8095
# Epoch 69/100
# 563/563 [==============================] - 52s 93ms/step - loss: 1.9231 - accuracy: 0.8204 - val_loss: 2.0385 - val_accuracy: 0.8107
# Epoch 70/100
# 563/563 [==============================] - 53s 94ms/step - loss: 1.9470 - accuracy: 0.8182 - val_loss: 2.0045 - val_accuracy: 0.8138
# Epoch 71/100
# 563/563 [==============================] - 53s 94ms/step - loss: 1.9515 - accuracy: 0.8179 - val_loss: 2.1135 - val_accuracy: 0.8040
# Epoch 72/100
# 563/563 [==============================] - 52s 93ms/step - loss: 1.9178 - accuracy: 0.8210 - val_loss: 2.0560 - val_accuracy: 0.8092
# Epoch 73/100
# 563/563 [==============================] - 53s 94ms/step - loss: 1.9509 - accuracy: 0.8178 - val_loss: 2.0156 - val_accuracy: 0.8129
# Epoch 74/100
# 563/563 [==============================] - 53s 94ms/step - loss: 1.9104 - accuracy: 0.8215 - val_loss: 2.0654 - val_accuracy: 0.8082
# Epoch 75/100
# 563/563 [==============================] - 52s 93ms/step - loss: 1.9564 - accuracy: 0.8172 - val_loss: 2.0338 - val_accuracy: 0.8113
# Epoch 76/100
# 563/563 [==============================] - 53s 93ms/step - loss: 1.9383 - accuracy: 0.8190 - val_loss: 2.0154 - val_accuracy: 0.8128
# Epoch 77/100
# 563/563 [==============================] - 53s 94ms/step - loss: 1.9572 - accuracy: 0.8172 - val_loss: 2.0425 - val_accuracy: 0.8104
# Epoch 78/100
# 563/563 [==============================] - 53s 93ms/step - loss: 1.9201 - accuracy: 0.8205 - val_loss: 2.0868 - val_accuracy: 0.8062
# Epoch 79/100
# 563/563 [==============================] - 52s 93ms/step - loss: 1.9650 - accuracy: 0.8164 - val_loss: 2.0174 - val_accuracy: 0.8128
# Epoch 80/100
# 563/563 [==============================] - 53s 94ms/step - loss: 1.9314 - accuracy: 0.8195 - val_loss: 2.0293 - val_accuracy: 0.8118
# Epoch 81/100
# 563/563 [==============================] - 53s 93ms/step - loss: 1.9215 - accuracy: 0.8202 - val_loss: 2.0475 - val_accuracy: 0.8101
# Epoch 82/100
# 563/563 [==============================] - 53s 94ms/step - loss: 1.9375 - accuracy: 0.8189 - val_loss: 2.0664 - val_accuracy: 0.8080
# Epoch 83/100
# 563/563 [==============================] - 53s 94ms/step - loss: 1.9434 - accuracy: 0.8182 - val_loss: 2.0286 - val_accuracy: 0.8116
# Epoch 84/100
# 563/563 [==============================] - 51s 90ms/step - loss: 1.9381 - accuracy: 0.8187 - val_loss: 2.0556 - val_accuracy: 0.8094
# Epoch 85/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9158 - accuracy: 0.8207 - val_loss: 2.0774 - val_accuracy: 0.8073
# Epoch 86/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9306 - accuracy: 0.8194 - val_loss: 1.9807 - val_accuracy: 0.8163
# Epoch 87/100
# 563/563 [==============================] - 51s 90ms/step - loss: 1.9453 - accuracy: 0.8180 - val_loss: 2.0928 - val_accuracy: 0.8062
# Epoch 88/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9259 - accuracy: 0.8198 - val_loss: 1.9905 - val_accuracy: 0.8153
# Epoch 89/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9550 - accuracy: 0.8170 - val_loss: 2.0890 - val_accuracy: 0.8065
# Epoch 90/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9055 - accuracy: 0.8214 - val_loss: 2.0793 - val_accuracy: 0.8078
# Epoch 91/100
# 563/563 [==============================] - 52s 92ms/step - loss: 1.9462 - accuracy: 0.8179 - val_loss: 1.9974 - val_accuracy: 0.8145
# Epoch 92/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9415 - accuracy: 0.8181 - val_loss: 2.0989 - val_accuracy: 0.8053
# Epoch 93/100
# 563/563 [==============================] - 51s 90ms/step - loss: 1.9282 - accuracy: 0.8195 - val_loss: 2.0155 - val_accuracy: 0.8129
# Epoch 94/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9334 - accuracy: 0.8189 - val_loss: 2.0385 - val_accuracy: 0.8108
# Epoch 95/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9406 - accuracy: 0.8183 - val_loss: 2.0600 - val_accuracy: 0.8090
# Epoch 96/100
# 563/563 [==============================] - 51s 90ms/step - loss: 1.8994 - accuracy: 0.8220 - val_loss: 2.0128 - val_accuracy: 0.8134
# Epoch 97/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9796 - accuracy: 0.8144 - val_loss: 2.0562 - val_accuracy: 0.8091
# Epoch 98/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9053 - accuracy: 0.8214 - val_loss: 2.0152 - val_accuracy: 0.8129
# Epoch 99/100
# 563/563 [==============================] - 51s 90ms/step - loss: 1.9374 - accuracy: 0.8185 - val_loss: 2.0965 - val_accuracy: 0.8055
# Epoch 100/100
# 563/563 [==============================] - 51s 91ms/step - loss: 1.9357 - accuracy: 0.8185 - val_loss: 2.0320 - val_accuracy: 0.8113

# %%
resnet50_model_tl_1.save('resnet50_tl_2')
# Out:
# [WARNING] save:__init__:233 - Found untraced functions such as %s while saving (showing %d of %d). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# [INFO   ] builder_impl:copy_assets_to_destination_dir:779 - Assets written to: %s
# INFO:tensorflow:Assets written to: resnet50_tl_2\assets
# INFO:tensorflow:Assets written to: resnet50_tl_2\assets

# %% [markdown]
# # VGG - U-Net model

# %%
model = VGG16(include_top=False,
                     weights='imagenet', 
                     input_shape=(256, 256, 3))
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
def VGGUNetModel(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES):
    
    vgg16_base = VGG16(include_top=False,
                     weights='imagenet', 
                     input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    
    # Create a new 'top' of the model (i.e. fully-connected layers).
    # This is 'bootstrapping' a new top_model onto the pretrained layers.
    l1 = vgg16_base.output
    
    x1 = vgg16_base.get_layer('block1_conv2').output
    x2 = vgg16_base.get_layer('block2_conv2').output
    x3 = vgg16_base.get_layer('block3_conv3').output
    x4 = vgg16_base.get_layer('block4_conv3').output
    x5 = vgg16_base.get_layer('block5_conv3').output
    
    u5 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(l1)
    c5 = BatchNormalization()(u5)
    d5 = Dropout(0.2)(c5)
    c5 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d5)
    c5 = BatchNormalization()(c5)
        
    # Decoder part - expansion
    # Up 1
    u6 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c5))
    u6 = concatenate([u6, x5], axis = 3)
    c6 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(u6)
    c6 = BatchNormalization()(c6)
    d6 = Dropout(0.2)(c6)
    c6 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d6)
    c6 = BatchNormalization()(c6)

    # Up 2    
    u7 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c6))
    u7 = concatenate([u7, x4], axis = 3)
    c7 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(u7)
    c7 = BatchNormalization()(c7)
    d7 = Dropout(0.2)(c7)
    c7 = Conv2D(512, (3, 3), activation = 'relu', padding = 'same')(d7)
    c7 = BatchNormalization()(c7)

    # Up 3
    u8 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c7))
    u8 = concatenate([u8, x3], axis = 3)
    c8 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(u8)
    c8 = BatchNormalization()(c8)
    d8 = Dropout(0.1)(c8)
    c8 = Conv2D(256, (3, 3), activation = 'relu', padding = 'same')(d8)
    c8 = BatchNormalization()(c8)

    # Up 4
    u9 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c8))
    u9 = concatenate([u9, x2], axis = 3)
    c9 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(u9)
    c9 = BatchNormalization()(c9)
    d9 = Dropout(0.1)(c9)
    c9 = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(d9)
    c9 = BatchNormalization()(c9)
    
    # Up 5
    u10 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(UpSampling2D(size = (2, 2))(c9))
    u10 = concatenate([u10, x1], axis = 3)
    c10 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(u10)
    c10 = BatchNormalization()(c10)
    d10 = Dropout(0.1)(c10)
    c10 = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(d10)
    c10 = BatchNormalization()(c10)

    outputs = Conv2D(N_CLASSES, (1, 1), activation = 'sigmoid')(c10)
    
    model = Model(vgg16_base.input, outputs, name = 'VGG_U-Net') 
    
    for layer in model.layers[:-41]:
        layer.trainable = False
    
    return model

# %%
vgg_unet_model = VGGUNetModel(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, N_CLASSES)
vgg_unet_model.compile(optimizer = OPTIMIZER (learning_rate = LEARNING_RATE), 
                      loss = LOSS, 
                      metrics = METRICS)
vgg_unet_model.summary()
# Out:
# Model: "VGG_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 256, 256, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 128, 128, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 128, 128, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 128, 128, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 64, 64, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 64, 64, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 32, 32, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 32, 32, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 16, 16, 512)  0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv2[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 8, 8, 512)    0           ['block5_conv3[0][0]']
#
#  conv2d (Conv2D)                (None, 8, 8, 512)    2359808     ['block5_pool[0][0]']
#
#  batch_normalization (BatchNorm  (None, 8, 8, 512)   2048        ['conv2d[0][0]']
#  alization)
#
#  dropout (Dropout)              (None, 8, 8, 512)    0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 8, 8, 512)    2359808     ['dropout[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 8, 8, 512)   2048        ['conv2d_1[0][0]']
#  rmalization)
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 512)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 512)  2359808     ['up_sampling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 16, 1024  0           ['conv2d_2[0][0]',
#                                 )                                 'block5_conv3[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_3[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 16, 16, 512)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 512)  2359808     ['dropout_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_4[0][0]']
#  rmalization)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 512)  0          ['batch_normalization_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 512)  2359808     ['up_sampling2d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 1024  0           ['conv2d_5[0][0]',
#                                 )                                 'block4_conv3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  4719104     ['concatenate_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 32, 32, 512)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  2359808     ['dropout_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 512)  0          ['batch_normalization_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 256)  1179904     ['up_sampling2d_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_8[0][0]',
#                                                                   'block3_conv3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 256)  1179904     ['concatenate_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_9[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 64, 64, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 256)  590080      ['dropout_3[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_10[0][0]']
#  rmalization)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 25  0          ['batch_normalization_7[0][0]']
#                                 6)
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 12  295040      ['up_sampling2d_3[0][0]']
#                                 8)
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_11[0][0]',
#                                 6)                                'block2_conv2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_3[0][0]']
#                                 8)
#
#  batch_normalization_8 (BatchNo  (None, 128, 128, 12  512        ['conv2d_12[0][0]']
#  rmalization)                   8)
#
#  dropout_4 (Dropout)            (None, 128, 128, 12  0           ['batch_normalization_8[0][0]']
#                                 8)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 12  147584      ['dropout_4[0][0]']
#                                 8)
#
#  batch_normalization_9 (BatchNo  (None, 128, 128, 12  512        ['conv2d_13[0][0]']
#  rmalization)                   8)
#
#  up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 12  0          ['batch_normalization_9[0][0]']
#                                 8)
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 64  73792       ['up_sampling2d_4[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_14[0][0]',
#                                 8)                                'block1_conv2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_4[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 256, 256, 64  256        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  dropout_5 (Dropout)            (None, 256, 256, 64  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 64  36928       ['dropout_5[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 256, 256, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 1)  65          ['batch_normalization_11[0][0]']
#
# ==================================================================================================
# Total params: 42,199,745
# Trainable params: 22,755,457
# Non-trainable params: 19,444,288
# __________________________________________________________________________________________________

# %%
vgg_unet_train = vgg_unet_model.fit(train_gen,
                                  validation_data=val_gen,
                                  epochs = 50,
                                  steps_per_epoch = STEPS_PER_EPOCH,
                                  validation_steps = VALIDATION_STEPS,
                                  verbose = True)
# Out:
# Epoch 1/50
# 281/281 [==============================] - 199s 675ms/step - loss: 0.3170 - accuracy: 0.8841 - val_loss: 3.4085 - val_accuracy: 0.7361
# Epoch 2/50
# 281/281 [==============================] - 162s 578ms/step - loss: 0.2117 - accuracy: 0.9165 - val_loss: 0.2297 - val_accuracy: 0.8989
# Epoch 3/50
# 281/281 [==============================] - 162s 578ms/step - loss: 0.1863 - accuracy: 0.9254 - val_loss: 0.3397 - val_accuracy: 0.8551
# Epoch 4/50
# 281/281 [==============================] - 162s 579ms/step - loss: 0.1693 - accuracy: 0.9330 - val_loss: 0.1850 - val_accuracy: 0.9276
# Epoch 5/50
# 281/281 [==============================] - 162s 578ms/step - loss: 0.1552 - accuracy: 0.9390 - val_loss: 0.4585 - val_accuracy: 0.8196
# Epoch 6/50
# 281/281 [==============================] - 162s 579ms/step - loss: 0.1425 - accuracy: 0.9440 - val_loss: 0.2136 - val_accuracy: 0.9161
# Epoch 7/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.1327 - accuracy: 0.9482 - val_loss: 0.1707 - val_accuracy: 0.9333
# Epoch 8/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.1159 - accuracy: 0.9548 - val_loss: 0.1803 - val_accuracy: 0.9299
# Epoch 9/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.1080 - accuracy: 0.9582 - val_loss: 0.2785 - val_accuracy: 0.9115
# Epoch 10/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.1006 - accuracy: 0.9615 - val_loss: 0.4764 - val_accuracy: 0.8473
# Epoch 11/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0862 - accuracy: 0.9671 - val_loss: 0.1821 - val_accuracy: 0.9361
# Epoch 12/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0805 - accuracy: 0.9695 - val_loss: 0.2454 - val_accuracy: 0.9323
# Epoch 13/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0722 - accuracy: 0.9723 - val_loss: 0.1767 - val_accuracy: 0.9376
# Epoch 14/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0653 - accuracy: 0.9750 - val_loss: 0.2128 - val_accuracy: 0.9338
# Epoch 15/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0601 - accuracy: 0.9769 - val_loss: 0.2028 - val_accuracy: 0.9365
# Epoch 16/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0578 - accuracy: 0.9777 - val_loss: 0.3431 - val_accuracy: 0.9156
# Epoch 17/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0562 - accuracy: 0.9782 - val_loss: 0.2347 - val_accuracy: 0.9370
# Epoch 18/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0496 - accuracy: 0.9807 - val_loss: 0.2013 - val_accuracy: 0.9417
# Epoch 19/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0529 - accuracy: 0.9794 - val_loss: 0.2085 - val_accuracy: 0.9353
# Epoch 20/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0483 - accuracy: 0.9811 - val_loss: 0.2872 - val_accuracy: 0.9280
# Epoch 21/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0468 - accuracy: 0.9817 - val_loss: 0.3184 - val_accuracy: 0.8974
# Epoch 22/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0440 - accuracy: 0.9827 - val_loss: 0.2075 - val_accuracy: 0.9387
# Epoch 23/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0431 - accuracy: 0.9829 - val_loss: 0.2688 - val_accuracy: 0.9379
# Epoch 24/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0470 - accuracy: 0.9816 - val_loss: 0.2357 - val_accuracy: 0.9382
# Epoch 25/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0418 - accuracy: 0.9836 - val_loss: 0.2240 - val_accuracy: 0.9376
# Epoch 26/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0402 - accuracy: 0.9841 - val_loss: 0.2610 - val_accuracy: 0.9357
# Epoch 27/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0388 - accuracy: 0.9845 - val_loss: 0.2372 - val_accuracy: 0.9316
# Epoch 28/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0363 - accuracy: 0.9854 - val_loss: 0.2604 - val_accuracy: 0.9388
# Epoch 29/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0408 - accuracy: 0.9839 - val_loss: 0.3173 - val_accuracy: 0.9073
# Epoch 30/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0370 - accuracy: 0.9852 - val_loss: 0.2577 - val_accuracy: 0.9365
# Epoch 31/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0359 - accuracy: 0.9856 - val_loss: 0.2826 - val_accuracy: 0.9290
# Epoch 32/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0363 - accuracy: 0.9854 - val_loss: 0.2559 - val_accuracy: 0.9382
# Epoch 33/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0334 - accuracy: 0.9865 - val_loss: 0.2622 - val_accuracy: 0.9381
# Epoch 34/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0370 - accuracy: 0.9852 - val_loss: 0.2523 - val_accuracy: 0.9302
# Epoch 35/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0394 - accuracy: 0.9842 - val_loss: 0.2058 - val_accuracy: 0.9391
# Epoch 36/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0307 - accuracy: 0.9875 - val_loss: 0.2564 - val_accuracy: 0.9388
# Epoch 37/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0299 - accuracy: 0.9877 - val_loss: 0.2920 - val_accuracy: 0.9267
# Epoch 38/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0316 - accuracy: 0.9871 - val_loss: 0.2938 - val_accuracy: 0.9365
# Epoch 39/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0332 - accuracy: 0.9865 - val_loss: 0.2724 - val_accuracy: 0.9396
# Epoch 40/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0310 - accuracy: 0.9874 - val_loss: 0.2642 - val_accuracy: 0.9401
# Epoch 41/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0273 - accuracy: 0.9888 - val_loss: 0.2729 - val_accuracy: 0.9403
# Epoch 42/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0271 - accuracy: 0.9888 - val_loss: 0.2920 - val_accuracy: 0.9364
# Epoch 43/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0321 - accuracy: 0.9869 - val_loss: 0.3637 - val_accuracy: 0.9224
# Epoch 44/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0295 - accuracy: 0.9880 - val_loss: 0.2747 - val_accuracy: 0.9385
# Epoch 45/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0301 - accuracy: 0.9877 - val_loss: 0.2530 - val_accuracy: 0.9403
# Epoch 46/50
# 281/281 [==============================] - 163s 582ms/step - loss: 0.0269 - accuracy: 0.9890 - val_loss: 0.3020 - val_accuracy: 0.9365
# Epoch 47/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0252 - accuracy: 0.9896 - val_loss: 0.2708 - val_accuracy: 0.9403
# Epoch 48/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0237 - accuracy: 0.9901 - val_loss: 0.2788 - val_accuracy: 0.9418
# Epoch 49/50
# 281/281 [==============================] - 163s 579ms/step - loss: 0.0265 - accuracy: 0.9891 - val_loss: 0.4129 - val_accuracy: 0.9264
# Epoch 50/50
# 281/281 [==============================] - 163s 580ms/step - loss: 0.0277 - accuracy: 0.9887 - val_loss: 0.2576 - val_accuracy: 0.9382

# %%
vgg_unet_model.save('vgg_unet_3')
# Out:
# [WARNING] save:__init__:233 - Found untraced functions such as %s while saving (showing %d of %d). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.
# [INFO   ] builder_impl:copy_assets_to_destination_dir:779 - Assets written to: %s
# INFO:tensorflow:Assets written to: vgg_unet_3\assets
# INFO:tensorflow:Assets written to: vgg_unet_3\assets
